# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Out:
# Streaming output truncated to the last 5000 lines.
# or: cc - vulnerable
#
# protecting: conj - vulnerable
#
# people: dobj - protecting
#
# with: prep - protecting
#
# any: det - health
#
# food: nmod - health
#
# /: punct - health
#
# health: pobj - with
#
# restrictionsNot: punct - Note
#
# checked: ROOT - checked
#
# for: prep - checked
#
# .: punct - checked
#
# Also: advmod - consider
#
# ,: punct - consider
#
# consider: ROOT - consider
#
# the: det - amount
#
# right: amod - amount
#
# amount: dobj - consider
#
# before: prep - consider
#
# intake: pobj - before
#
# .: punct - consider
#
#
#
#
# : dep - .
#
# Pains: nsubj - are
#
# and: cc - Pains
#
# folk: compound - medicine
#
# medicine: conj - Pains
#
#
# : dep - medicine
#
# There: expl - are
#
# are: ROOT - are
#
# simple: amod - ways
#
# ways: attr - are
#
# and: cc - ways
#
# medicine: conj - ways
#
# in: prep - ways
#
# folk: compound - medicine
#
# medicine: pobj - in
#
# for: prep - ways
#
# a: det - variety
#
# ...
