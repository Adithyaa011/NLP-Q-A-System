# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Out:
# ['fungi',
#  'olive',
#  'freezing',
#  'fluids',
#  'virgin',
#  'olive oil',
#  'soft - deodorization',
#  'phenolic compounds',
#  'mass spectrometry',
#  'ion mobility spectrometry',
#  'nutrients review',
#  'olive oil',
#  'compounds',
#  'coronary artery disease',
#  'nutrition',
#  'coronary',
#  'hydro',
#  'adhesion',
#  'signaling cascade',
#  'olive oil',
#  'statistical',
#  'olive oils',
#  'triacylgly',
#  '- chemical characteristics',
#  'olives',
#  'olive oil',
#  'oil composition',
#  'olive oils',
#  'composition',
#  'properties',
#  'oleo science',
#  'japan oil chemists ’ society',
#  'composition',
#  'emulsion',
#  '- tion',
#  'and saturated fat',
#  'fatty acid',
#  'liquid',
#  'glycerides',
#  'food products',
#  'oleo science',
#  'molecular profiling',
#  'olive',
#  'fraction',
#  'mass spectrom',
#  'mass spectrometry',
#  'olive oil',
#  'virgin olive oil',
#  'virgin olive oil',
#  'olive oil',
#  'virgin olive oil',
#  'fatty acids',
#  'compounds',
#  'olive',
#  'chronic diseases',
#  'olive',
#  'obesity',
#  'cardiovascular',
#  'obesity',
#  'obesity',
#  'surface expression',
#  'signalling pathway activation',
#  'platelets',
#  'platelet',
#  'surgery',
#  'obesity',
#  'thermal desorption',
#  'gas chromatography',
#  'spectrometry',
#  'classification',
#  'american oil chemists ’',
#  '1h - nmr',
#  'fatty acid composition',
#  'edible oils',
#  'characterization',
#  'oils and fats',
#  'olive',
#  'molecular sciences',
#  'health',
#  'beneﬁ',
#  'olive oil',
#  'polyphenols',
#  'neuroscience',
#  'science and',
#  'of biomaterials and biomole',
#  'effects',
#  'natural plant',
#  'human body',
#  'compounds',
#  'morbidity',
#  'diseases',
#  'color',
#  'olive',
#  'olive',
#  'nutritional',
#  'supplements',
#  'agents',
#  'olive oil',
#  'observational studies',
#  'biostatistics',
#  'olive oil',
#  'olive oil',
#  'olive oil',
#  'olive',
#  'olive',
#  'olive',
#  'olive',
#  'olive',
#  'olive',
#  'breast',
#  'cancer',
#  'breast',
#  'proton nmr',
#  'proton nmr',
#  'Diﬀusion',
#  'olive oil',
#  'vegetable oils',
#  'metric',
#  'olive oils',
#  'olive oils',
#  'diﬀerent',
#  'olive oils',
#  'vegetable',
#  'diﬀusion',
#  'olive oils',
#  'vegetable oil',
#  'vegetable oils',
#  'diﬀusometry',
#  'vegetable oil',
#  'olive oil',
#  'olives',
#  'diﬀerent',
#  'olive oils',
#  'mixture',
#  'principal component analysis',
#  'olive',
#  'principal',
#  'proton spectra',
#  'olive',
#  'gelators',
#  'lipid digestion',
#  'olive oil',
#  'olive oil',
#  'polyph',
#  'oleo - gel',
#  'digestion',
#  'free fatty acid release',
#  'micelle formation',
#  'olive',
#  'decision',
#  'olive oil',
#  'quality of lipids',
#  'biology',
#  'beta - to',
#  'gamma - tocopher',
#  'sterol',
#  'olive oil',
#  'olive',
#  'tria - cylgly',
#  'sterol',
#  'olive',
#  'accuracy',
#  'dna methylation',
#  'surveillance',
#  'trans - fatty acids',
#  'trans fatty acids',
#  'drugs',
#  'tabebuia',
#  'olive oil',
#  'discrimination',
#  'diole',
#  'extraction',
#  'food chem',
#  'olive',
#  'storage',
#  'virgin olive oil',
#  'bosana',
#  'stone',
#  'food che',
#  'malax',
#  'oxygen',
#  'olive oil',
#  'olive',
#  'extraction',
#  'decanter',
#  'processing',
#  'food bioproces',
#  '- phase decanter',
#  'extraction',
#  'sensory char',
#  'olive',
#  'hazelnut',
#  'food additives &',
#  'raman spectrometers',
#  'spectroscopy',
#  'hazelnut',
#  'hazelnut',
#  'systemic',
#  'raman spectrometer',
#  'olive',
#  'olive',
#  'compound',
#  'transfer',
#  'compounds',
#  'food chemistry',
#  'learning',
#  'olive oil',
#  'chemical composition',
#  'olive tree, subtropical crops and viticulture',
#  'olive oil',
#  'composition',
#  'classification',
#  'artificial intelligent models',
#  'machine learning',
#  'olive oil',
#  'classification',
#  'artificial intelligence model',
#  'learning algorithm',
#  'olive oil',
#  'health',
#  'lifestyle',
#  'olive oil',
#  'virgin olive oil',
#  'olive products',
#  'accumulation',
#  'organs',
#  'adipocytes',
#  'organ dysfunction',
#  'olive',
#  'inflammatory effects',
#  'olive',
#  'olive',
#  'serum',
#  'liver',
#  'injury',
#  'olive',
#  'synthesis',
#  'lipid degradation',
#  'olive',
#  'factors',
#  'olive',
#  'olive',
#  'trigly',
#  'biomolecules',
#  'mechanical properties',
#  'infrared',
#  'computer',
#  'machine',
#  'electronic',
#  'spectroscopy',
#  'olive',
#  'index',
#  'properties',
#  'fatty liver',
#  'gas - troente',
#  'fatty liver disease',
#  'metabolic syndrome',
#  'fatty liver',
#  'insulin',
#  'fatty acids',
#  'liver',
#  'teins',
#  'fatty liver disease',
#  'fatty acid',
#  'insulin',
#  'triacylglycerols',
#  'olive oil',
#  'chromatography',
#  'mass spectrometry',
#  'triacylglycerols',
#  'gas chromatography',
#  'analysis',
#  'vegetable oils',
#  'foods',
#  'triacylglycerols',
#  'plant oils',
#  'olive oil',
#  'triglycerides',
#  'gas chromatography',
#  'gas chromatography',
#  'triacylgly',
#  'cocoa butter',
#  'milk fat',
#  'chocolate fat',
#  'coronary heart disease',
#  'analyses',
#  'observational studies',
#  '- 3 fatty acids',
#  'polyphenols',
#  'oleo science',
#  'japan oil chemists ’ society',
#  'screening',
#  'tyrosol',
#  'including fats and',
#  'olive',
#  'flavor',
#  'olive oil',
#  'olive',
#  'olive oil',
#  'olive',
#  'vegetable oils',
#  'olive oil',
#  'food chemistry',
#  'olive oil',
#  'opto - electronics technology',
#  'olive',
#  'raman spectroscopy',
#  'oleic acids',
#  'laser',
#  'acids',
#  'linoleic acids',
#  'density functional',
#  'support vector regression',
#  'β - carote',
#  'different volume ratios',
#  'laser',
#  'olive',
#  'olive pomace',
#  'sensory defects',
#  'biological phenomena',
#  'metric',
#  'olive pomace',
#  'diﬀerent',
#  'defective oils',
#  'volatile fraction',
#  'volatiles',
#  'volatile',
#  'alcohol',
#  'markers',
#  'olive',
#  'alcohol',
#  'hydroxy',
#  'olive oil',
#  'olive',
#  'olive',
#  'muddy sediment defect',
#  'virgin olive oil',
#  'olive',
#  'olive oil',
#  'vegetable oil',
#  'oleic acid',
#  'compounds',
#  'volatile organic compounds',
#  'bioactive ph',
#  'review',
#  'olive oil',
#  'phenols',
#  'fatty liver disease',
#  'paola priore1',
#  'biology',
#  'fatty liver disease',
#  'chronic liver disease',
#  'olive',
#  'olive',
#  'hepatic',
#  'olive oil',
#  'mitochondrial dysfunction',
#  'olive oil',
#  'phenols',
#  'alcoholic fatty liver disease',
#  'olive',
#  'fatty liver disease',
#  'fatty liver disease',
#  'chronic',
#  'liver disease',
#  'liver damage',
#  'hepatitis c virus',
#  'oleo science',
#  'chemists ’ society',
#  'olive',
#  'obese',
#  'oxygen',
#  'ozone',
#  'bacteria',
#  'food disinfectants',
#  'sodium',
#  'oleo science',
#  'japan oil chemists ’ society',
#  'chemical changes',
#  'olive',
#  'gargouri',
#  'labor',
#  'olive',
#  'nutritional',
#  'acids',
#  'chemical',
#  'tocopher',
#  'polyphenols',
#  'aromatic hydrocarbon',
#  'alipha',
#  'sterols',
#  'volatile',
#  'pounds',
#  'nutrients',
#  'olive',
#  'storage',
#  'cardiovascular diseases',
#  'oxida',
#  'inﬂam',
#  'extra virgin olive oils',
#  'fraction',
#  'olive oil screening',
#  'proton nmr',
#  'olive oil screening',
#  'proton nmr spectra',
#  'olive oils',
#  'seed oils',
#  'principal component analysis',
#  'olive oils',
#  'spectra',
#  'proton nm',
#  'virgin',
#  'olive oil',
#  'organoleptic properties',
#  'mass spectrometry',
#  'linear discriminant analysis',
#  'vector machine',
#  'least square discrim',
#  'orthogonal projection to latent structure - discriminant analysis',
#  'counter propagation artificial neural networks',
#  'self - organizing maps',
#  'investigation',
#  'olive',
#  'diseases',
#  'olive',
#  'pheno',
#  'compounds',
#  'damage',
#  'blood hdl - cholesterol',
#  'blood pressure',
#  'inﬂammatory properties',
#  'olive oil',
#  'olive oil',
#  'computer vision chemometrics',
#  'edible oil',
#  'quence of light',
#  'regression',
#  'ultraviolet',
#  'vegetable oil',
#  'olive oil',
#  'edible oil',
#  'olive oil',
#  'fatty',
#  'vitamin',
#  'chemistry',
#  'analytical methods',
#  'olive oil characterization',
#  'classiﬁcation',
#  '13c nmr',
#  'gas chromatography',
#  'nantes',
#  'triacylglycerols',
#  'fatty acids',
#  'olive oil',
#  'linear regression',
#  '13c - in',
#  'fatty acids',
#  'linear',
#  'olive oils',
#  'gas chromatography',
#  'olive oil',
#  'analytical variables',
#  'fatty acid quan',
#  'olive oils',
#  'edible oils',
#  'networks',
#  'mathematical',
#  'brain',
#  'harvest',
#  'oil packaging',
#  'molecules review',
#  'olive oil',
#  'olive oil',
#  'olive oil',
#  'aging',
#  'epigenetics',
#  'dna methyl',
#  'ion mobility',
#  'virgin',
#  'inspection',
#  'class',
#  'electronic',
#  'spectroscopy',
#  'peroxide',
#  'electronic',
#  'virgin',
#  'virgin olive oil',
#  'virgin olive',
#  'sciences',
#  'extract',
#  'and clinic biomedical sciences',
#  'pharmaceutical and nutraceutical',
#  'blended oils',
#  'blended',
#  'olive',
#  'atherosclerosis',
#  'ather',
#  'olive',
#  'plaque formation',
#  'olive',
#  'fatty acids',
#  'carrageenan',
#  'alginate',
#  'olive',
#  'carrageenan',
#  'alginate',
#  'olive oil',
#  'cardiovascular disease',
#  'cancer',
#  'olive oil',
#  'legumes',
#  'olive oil',
#  'mediterranean',
#  'olive oil',
#  'olive',
#  'foods',
#  'olive oil',
#  'nut consumption',
#  'olive',
#  'virgin olive oil',
#  'cancer',
#  'olive',
#  'olive oil',
#  'olive',
#  'bitterness',
#  'bitterness',
#  'olive',
#  'extraction',
#  'liquid',
#  'liquid extraction',
#  'bitterness',
#  'pigments',
#  'olive oils',
#  'foods',
#  'food che',
#  'adult',
#  'plant oils',
#  'sterols',
#  'food che',
#  'fraud',
#  'olive oils',
#  'adult',
#  'spectroscopy',
#  'compounds',
#  'olive oil',
#  'nutrients',
#  'olive oil',
#  'extra',
#  'virgin',
#  'olive oil',
#  'virgin',
#  'olive oil',
#  'natural products',
#  'olive',
#  'olive oil',
#  'mass spectrometry',
#  'phenolic',
#  'triterpenic compounds',
#  'phenolic compounds',
#  'pinoc',
#  'hydroxyty',
#  'secoiridoids',
#  'lignans',
#  'heat map',
#  'sensors',
#  'cell - ftir spectroscopy',
#  'oil stability',
#  'hydroperoxides',
#  'cardiovascular diseases',
#  'stress',
#  'inflammatory processes',
#  'changes',
#  'oil stability',
#  'hydroperoxides',
#  'ozone',
#  'bacterial',
#  'ozone',
#  'surgi - cal',
#  'olive oil',
#  'olive',
#  'cleaner',
#  'tation',
#  'clean',
#  'olive',
#  'biomass potential',
#  'heating',
#  'energy',
#  'pastoral',
#  'glass',
#  'olive oil',
#  'energy',
#  'olive oil',
#  'enzymes',
#  'virgin',
#  'virgin',
#  'virgin',
#  'olive',
#  'virgin',
#  'alcohol de',
#  'alcohol acetyl',
#  'dhpea',
#  'dhpea',
#  'food chemistry',
#  'adult',
#  'olive',
#  'olive oil',
#  'variable selection',
#  'olive',
#  'accuracy',
#  'olive',
#  'olive',
#  'olive',
#  'volatile compounds',
#  'analytical approaches',
#  'like activity',
#  'processing markers',
#  'milling',
#  'molecular',
#  'conditions',
#  'malaxation',
#  'compounds',
#  'voltammetric ﬁngerprinting',
#  'olive oil',
#  'inorganic and analytical chemistry',
#  'greece',
#  'voltammetric',
#  'ﬁngerprint',
#  'dif - ferentiation',
#  'olive',
#  'olive oils',
#  'olive oil',
#  'olive oil',
#  'voltammetry',
#  'principal component analysis',
#  'voltammetric ﬁngerprinting',
#  'chemometric',
#  'olive po',
#  'cyclic voltammog',
#  'olive oils',
#  'olive oils',
#  'olive pomace oils',
#  'seed oils',
#  'liclo4',
#  'electrolyte',
#  'cyclic voltammetry',
#  'extracts',
#  'cyclic vol - tammogram',
#  'square',
#  'analysis',
#  'mineral oil',
#  'leaks',
#  'chrom',
#  'platform',
#  'oleoca',
#  'oleacein',
#  'olive oil',
#  'extra virgin olive oils',
#  'oleuropein',
#  'ligstroside aglycon',
#  'oleoca',
#  'olive oil',
#  'aging',
#  'temperature',
#  'olive oil',
#  'cause',
#  'food packaging',
#  'recherche et d ’ analyse physico - chimique',
#  'packaging',
#  'higher edu - cation and',
#  'olive',
#  'exponential',
#  'adult',
#  'corn oil',
#  'olive oil',
#  'corn oil',
#  'raman spectroscopy',
#  'exponential',
#  'intensity',
#  'raman spectroscopy',
#  'changes',
#  'fraction',
#  'raman spectroscopy',
#  'olive oil',
#  'olive',
#  'olive oil',
#  'nigel',
#  'sativa oil',
#  'hepatotoxicity',
#  'liver',
#  'hepatotherapeutic agents',
#  'olive oil',
#  'liver damage',
#  'injected',
#  'olive',
#  'olive',
#  'total biliru',
#  'lipid peroxide',
#  'total',
#  'interleuki',
#  'total protein',
#  'albumin an',
#  'histology',
#  'inflammation',
#  'damage',
#  'olive oil',
#  'tests',
#  'liver',
#  'olive',
#  'inflammatory in',
#  'olive',
#  'sativa oil',
#  'nigel',
#  'olive',
#  'che - mometric',
#  'ft - nir',
#  'ir spectroscopy',
#  'fish fillet',
#  'food science',
#  'acids',
#  'olive',
#  'nanostructures',
#  'fatty acids',
#  'delivery for - mulation',
#  'virgin olive',
#  'adul - teration',
#  'computers',
#  'electronics in agriculture',
#  'oleo science',
#  'japan',
#  'oil chemists ’ society',
#  'oil characteristics',
#  'olive varieties',
#  'maria lo',
#  'olive harvest',
#  'olive',
#  'olive',
#  'phenols',
#  'sterols',
#  'sensory profile',
#  'endoscopy',
#  'imaging',
#  'bowel',
#  'serum catestatin',
#  'arterial stiffness parameters',
#  'matrix gla protein',
#  'microarchitecture',
#  'olive oil',
#  'model',
#  'dexame',
#  'histopathological changes',
#  'olive oil',
#  'olive oil',
#  'olive oil',
#  'bone mineral',
#  'terpenoids',
#  'compounds',
#  'heads',
#  'micro',
#  'changes',
#  'olive oil',
#  'volatile organic compounds',
#  'status',
#  'light environment',
#  'analysis',
#  'approaches',
#  'liquid chromatography',
#  'mass spectrometry',
#  'aroma',
#  'virgin olive oils',
#  'fatty acids',
#  'olive',
#  'cultivar',
#  'ingredients',
#  'polar',
#  'olive oils',
#  'platelet hyper',
#  'obesity',
#  'olive oil',
#  'olive oil',
#  'plate',
#  'platelet activation',
#  'diet composition',
#  'olive oil',
#  'platelet',
#  'selectin',
#  'olive oil',
#  'olive oil',
#  'platelet activation',
#  'plate',
#  'olive',
#  'analyses',
#  'agricultural census',
#  'cultural statistics',
#  'olive',
#  'palestinian olive',
#  'olive',
#  'olive',
#  'olive',
#  'hydrolyzable phenolic compounds',
#  'network',
#  'classiﬁcation',
#  'edible oils',
#  'thermal analysis',
#  'calorimetry',
#  'near infrared spectroscopy',
#  'olive fruit and oil',
#  'near infrared spectroscopy',
#  'class',
#  'pyrolysis',
#  'fertilizing effect',
#  'olive mill waste',
#  'compost',
#  'biodegradation',
#  'sensory',
#  '- ation',
#  'virgin olive',
#  'neural network',
#  'agriculture',
#  'olive oil',
#  'mapping',
#  'proton transfer reaction',
#  'mass spectrometry',
#  'alteration',
#  'food chemistry',
#  'sciences',
#  'electrochemical',
#  'biosensors',
#  'electrochemical sensors',
#  'biosen',
#  'arrays',
#  'sensory proﬁle',
#  'phenolic compounds',
#  'olive',
#  'time kill curves',
#  'olive',
#  'strain inhibition',
#  'olive',
#  'biofilm',
#  'olive',
#  'virgin olive oil',
#  'olive oil',
#  'western',
#  'chloral hydrate',
#  'liver',
#  'weight',
#  'weight',
#  'extra - virgin - olive oils',
#  'skin manifestation',
#  'toxic syndrome',
#  'dietetic products',
#  'saturated fatty acids',
#  'ldl - cholesterol',
#  'dietetic products',
#  'edible fat',
#  'european food',
#  'authority',
#  'olive',
#  'secoir',
#  'secoir',
#  'olive oils',
#  'samples',
#  'olive',
#  'metabolism',
#  'phenols',
#  'compounds',
#  'biological rhythms',
#  'olive oils',
#  'composition',
#  'virgin olive oils',
#  'chemist',
#  'olive oil',
#  'calib',
#  'analysis',
#  'authentication',
#  'olive',
#  'determination',
#  'olive',
#  'spectrometer',
#  'trans fat',
#  'sugar',
#  'food chemistry',
#  'mineral',
#  'olive oils',
#  'mineral',
#  'olive',
#  'leaks',
#  'liquid chromatography',
#  'chromatography',
#  'ionization detection',
#  'gas chromatographic platform',
#  'harvesting',
#  'mineral oil hydro',
#  'petroleum distillation products',
#  'alcoholic',
#  'fatty liver disease',
#  'carbohydrates',
#  'fatty liver disease',
#  'olive oil',
#  'nitro - fatty acids',
#  'alcoholic fatty liver disease',
#  'metabolic syndrome',
#  'intervention',
#  'cooking',
#  'fatty acids',
#  'control',
#  'fatty liver',
#  'diabetes',
#  'cardiovascular',
#  'coronary artery disease',
#  'inflammation',
#  'ather',
#  'nutrients review',
#  'olive oil',
#  'color',
#  'cancer',
#  'colorectal cancer',
#  'mediterranean',
#  'color',
#  'olive',
#  'olive',
#  'supplements',
#  'cancer',
#  'sensors',
#  'olive',
#  'evaluation',
#  'olive',
#  'olive',
#  'different',
#  'gelators',
#  'oleogelation',
#  'mechanisms',
#  'food hydro',
#  'radical',
#  '- chemical parameters',
#  'infrared spectroscopy',
#  'parameters',
#  'free acidity',
#  'peroxide value',
#  'errors',
#  'photooxidation',
#  'olive',
#  'carotenoids',
#  'chlorophylls',
#  'virgin',
#  'effect',
#  'virgin',
#  'pigments',
#  'virgin',
#  'virgin',
#  'virgin',
#  'stability',
#  'olive oil council',
#  'olive oil balance',
#  'market',
#  'olive',
#  'trade',
#  'olive oil',
#  'olive - pomac',
#  'charac - teristic',
#  'olive',
#  'meth - ods',
#  'spectroscopy',
#  'spanish',
#  'near - infrared reﬂectance spectroscopic analysis',
#  'food che',
#  'oil acc',
#  'abstract fibroblasts',
#  'tissue',
#  'ccd -',
#  'human fibroblast',
#  'cell proliferation',
#  'actin',
#  'sensor',
#  'evaluation',
#  'techniques',
#  'olive',
#  'properties',
#  'chilling',
#  'freezing',
#  'injuries',
#  'olive',
#  'harvested',
#  'freezing condition',
#  'extraction',
#  'common analyses',
#  'total ph',
#  'storage',
#  'extracted',
#  'effect',
#  'research',
#  'olive oil',
#  'deleterious',
#  'olive',
#  'conventional',
#  'dexame',
#  'serum',
#  'histopathological changes',
#  'olive oil',
#  'olive oil',
#  'bone thickness',
#  ...]

# %%
# Out:
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==4.0.0-rc1)
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2023.11.17)
# Collecting hstspreload (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hstspreload-2023.1.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.0)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 15.2 MB/s eta 0:00:00
# Collecting idna==2.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.1 MB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.7 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.6 MB/s eta 0:00:00
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 6.7 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=5b6db9d4fd64fc76998c9f4c0d019fff0900dfe7b872ca5ef09e82605133dd29
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2023.1.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
# Out:
# An error occurred: The read operation timed out
# An error occurred: The read operation timed out
# An error occurred: The read operation timed out
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: The read operation timed out
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# An error occurred: 'Translator' object has no attribute 'raise_Exception'
# fungi -> பூஞ்சை
# olive -> ஆலிவ்
# freezing -> உறைபனி
# fluids -> திரவங்கள்
# virgin -> கன்னி
# olive oil -> ஆலிவ் எண்ணெய்
# soft - deodorization -> மென்மையான - டியோடரைசேஷன்
# phenolic compounds -> பினோலிக் கலவைகள்
# mass spectrometry -> பெருமளவிலான நிறமாலையியல்
# ion mobility spectrometry -> அயன் மொபிலிட்டி ஸ்பெக்ட்ரோமெட்ரி
# nutrients review -> ஊட்டச்சத்துக்கள் மதிப்பாய்வு
# olive oil -> ஆலிவ் எண்ணெய்
# compounds -> கலவைகள்
# coronary artery disease -> கரோனரி தமனி நோய்
# nutrition -> ஊட்டச்சத்து
# coronary -> கரோனரி
# hydro -> ஹைட்ரோ
# adhesion -> ஒட்டுதல்
# signaling cascade -> சமிக்ஞை அடுக்கு
# olive oil -> ஆலிவ் எண்ணெய்
# statistical -> புள்ளிவிவர
# olive oils -> ஆலிவ் எண்ணெய்கள்
# triacylgly -> ட்ரையசில்கி
# - chemical characteristics -> - வேதியியல் பண்புகள்
# olives -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# oil composition -> எண்ணெய் கலவை
# olive oils -> ஆலிவ் எண்ணெய்கள்
# composition -> கலவை
# properties -> பண்புகள்
# oleo science -> ஓலியோ அறிவியல்
# japan oil chemists ’ society -> ஜப்பான் எண்ணெய் வேதியியலாளர்கள் சமூகம்
# composition -> கலவை
# emulsion -> குழம்பு
# - tion -> - tion
# and saturated fat -> மற்றும் நிறைவுற்ற கொழுப்பு
# fatty acid -> கொழுப்பு அமிலம்
# liquid -> திரவ
# glycerides -> கிளிசரைடுகள்
# food products -> உணவு பொருட்கள்
# oleo science -> ஓலியோ அறிவியல்
# molecular profiling -> மூலக்கூறு விவரக்குறிப்பு
# olive -> ஆலிவ்
# fraction -> பின்னம்
# mass spectrom -> வெகுஜன நிறமாலை
# mass spectrometry -> பெருமளவிலான நிறமாலையியல்
# olive oil -> ஆலிவ் எண்ணெய்
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# fatty acids -> கொழுப்பு அமிலங்கள்
# compounds -> கலவைகள்
# olive -> ஆலிவ்
# chronic diseases -> நாட்பட்ட நோய்கள்
# olive -> ஆலிவ்
# obesity -> உடல் பருமன்
# cardiovascular -> இருதய
# obesity -> உடல் பருமன்
# obesity -> உடல் பருமன்
# surface expression -> மேற்பரப்பு வெளிப்பாடு
# signalling pathway activation -> சமிக்ஞை பாதை செயல்படுத்தல்
# platelets -> பிளேட்லெட்டுகள்
# platelet -> பிளேட்லெட்
# surgery -> அறுவை சிகிச்சை
# obesity -> உடல் பருமன்
# thermal desorption -> வெப்ப பற்றாக்குறை
# gas chromatography -> வாயு நிறமூர்த்தம்
# spectrometry -> நிறமாலை
# classification -> வகைப்பாடு
# american oil chemists ’ -> அமெரிக்க எண்ணெய் வேதியியலாளர்கள் ’
# 1h - nmr -> 1 எச் - என்.எம்.ஆர்
# fatty acid composition -> கொழுப்பு அமில கலவை
# edible oils -> உண்ணக்கூடிய எண்ணெய்கள்
# characterization -> தன்மை
# oils and fats -> எண்ணெய்கள் மற்றும் கொழுப்புகள்
# olive -> ஆலிவ்
# molecular sciences -> மூலக்கூறு அறிவியல்
# health -> ஆரோக்கியம்
# beneﬁ -> ken ﬁ
# olive oil -> ஆலிவ் எண்ணெய்
# polyphenols -> பாலிபினால்கள்
# neuroscience -> நரம்பியல்
# science and -> அறிவியல் மற்றும்
# of biomaterials and biomole -> பயோ மெட்டீரியல்ஸ் மற்றும் பயோமோல்
# effects -> விளைவுகள்
# natural plant -> இயற்கை ஆலை
# human body -> மனித உடல்
# compounds -> கலவைகள்
# morbidity -> நோயுற்ற தன்மை
# diseases -> நோய்கள்
# color -> நிறம்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# nutritional -> ஊட்டச்சத்து
# supplements -> கூடுதல்
# agents -> முகவர்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# observational studies -> அவதானிப்பு ஆய்வுகள்
# biostatistics -> பயோஸ்டாடிஸ்டிக்ஸ்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# breast -> மார்பகம்
# cancer -> புற்றுநோய்
# breast -> மார்பகம்
# proton nmr -> புரோட்டான் என்.எம்.ஆர்
# proton nmr -> புரோட்டான் என்.எம்.ஆர்
# Diﬀusion -> Di ﬀ usion
# olive oil -> ஆலிவ் எண்ணெய்
# vegetable oils -> தாவர எண்ணெய்கள்
# metric -> மெட்ரிக்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# diﬀerent -> di ﬀ erent
# olive oils -> ஆலிவ் எண்ணெய்கள்
# vegetable -> காய்கறி
# diﬀusion -> di ﬀ usion
# olive oils -> ஆலிவ் எண்ணெய்கள்
# vegetable oil -> தாவர எண்ணெய்
# vegetable oils -> தாவர எண்ணெய்கள்
# diﬀusometry -> டி ﬀ யூசோமெட்ரி
# vegetable oil -> தாவர எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# olives -> ஆலிவ்
# diﬀerent -> di ﬀ erent
# olive oils -> ஆலிவ் எண்ணெய்கள்
# mixture -> கலவை
# principal component analysis -> முதன்மை கூறு பகுப்பாய்வு
# olive -> ஆலிவ்
# principal -> முதன்மை
# proton spectra -> புரோட்டான் ஸ்பெக்ட்ரா
# olive -> ஆலிவ்
# gelators -> ஜெலேட்டர்கள்
# lipid digestion -> லிப்பிட் செரிமானம்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# polyph -> பாலிப்
# oleo - gel -> ஓலியோ - ஜெல்
# digestion -> செரிமானம்
# free fatty acid release -> இலவச கொழுப்பு அமில வெளியீடு
# micelle formation -> மைக்கேல் உருவாக்கம்
# olive -> ஆலிவ்
# decision -> முடிவு
# olive oil -> ஆலிவ் எண்ணெய்
# quality of lipids -> லிப்பிட்களின் தரம்
# biology -> உயிரியல்
# beta - to -> பீட்டா - க்கு
# gamma - tocopher -> காமா - டோகோபெரோல்
# sterol -> ஸ்டெரால்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# tria - cylgly -> முத்தரப்பு - சிலிங்கி
# sterol -> ஸ்டெரால்
# olive -> ஆலிவ்
# accuracy -> துல்லியம்
# dna methylation -> டி.என்.ஏ மெத்திலேஷன்
# surveillance -> கண்காணிப்பு
# trans - fatty acids -> டிரான்ஸ் - கொழுப்பு அமிலங்கள்
# trans fatty acids -> டிரான்ஸ் கொழுப்பு அமிலங்கள்
# drugs -> மருந்துகள்
# tabebuia -> Tabebuia
# olive oil -> ஆலிவ் எண்ணெய்
# discrimination -> பாகுபாடு
# diole -> டயோல்
# extraction -> பிரித்தெடுத்தல்
# food chem -> உணவு செம்
# olive -> ஆலிவ்
# storage -> சேமிப்பு
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# bosana -> போசானா
# stone -> கல்
# food che -> உணவு சே
# malax -> மலாக்ஸ்
# oxygen -> ஆக்ஸிஜன்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# extraction -> பிரித்தெடுத்தல்
# decanter -> டிகாண்டர்
# processing -> செயலாக்கம்
# food bioproces -> உணவு பயோபிரசஸ்
# - phase decanter -> - கட்ட டிகாண்டர்
# extraction -> பிரித்தெடுத்தல்
# sensory char -> சென்சரி கரி
# olive -> ஆலிவ்
# hazelnut -> ஹேசல்நட்
# food additives & -> உணவு சேர்க்கைகள் &
# raman spectrometers -> ராமன் ஸ்பெக்ட்ரோமீட்டர்கள்
# spectroscopy -> ஸ்பெக்ட்ரோஸ்கோபி
# hazelnut -> ஹேசல்நட்
# hazelnut -> ஹேசல்நட்
# systemic -> முறையான
# raman spectrometer -> ராமன் ஸ்பெக்ட்ரோமீட்டர்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# compound -> கூட்டு
# transfer -> இடமாற்றம்
# compounds -> கலவைகள்
# food chemistry -> உணவு வேதியியல்
# learning -> கற்றல்
# olive oil -> ஆலிவ் எண்ணெய்
# chemical composition -> வேதியியல் கலவை
# olive tree, subtropical crops and viticulture -> ஆலிவ் மரம், துணை வெப்பமண்டல பயிர்கள் மற்றும் வைட்டிகல்ச்சர்
# olive oil -> ஆலிவ் எண்ணெய்
# composition -> கலவை
# classification -> வகைப்பாடு
# artificial intelligent models -> செயற்கை நுண்ணறிவு மாதிரிகள்
# machine learning -> இயந்திர வழி கற்றல்
# olive oil -> ஆலிவ் எண்ணெய்
# classification -> வகைப்பாடு
# artificial intelligence model -> செயற்கை நுண்ணறிவு மாதிரி
# learning algorithm -> கற்றல் வழிமுறை
# olive oil -> ஆலிவ் எண்ணெய்
# health -> ஆரோக்கியம்
# lifestyle -> வாழ்க்கை
# olive oil -> ஆலிவ் எண்ணெய்
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# olive products -> ஆலிவ் தயாரிப்புகள்
# accumulation -> குவிப்பு
# organs -> உறுப்புகள்
# adipocytes -> அடிபோசைட்டுகள்
# organ dysfunction -> உறுப்பு செயலிழப்பு
# olive -> ஆலிவ்
# inflammatory effects -> அழற்சி விளைவுகள்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# serum -> சீரம்
# liver -> கல்லீரல்
# injury -> காயம்
# olive -> ஆலிவ்
# synthesis -> தொகுப்பு
# lipid degradation -> லிப்பிட் சிதைவு
# olive -> ஆலிவ்
# factors -> காரணிகள்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# trigly -> ட்ராக்லி
# biomolecules -> உயிர் மூலக்கூறுகள்
# mechanical properties -> இயந்திர பண்புகளை
# infrared -> அகச்சிவப்பு
# computer -> கணினி
# machine -> இயந்திரம்
# electronic -> மின்னணு
# spectroscopy -> ஸ்பெக்ட்ரோஸ்கோபி
# olive -> ஆலிவ்
# index -> குறியீட்டு
# properties -> பண்புகள்
# fatty liver -> கொழுப்பு கல்லீரல்
# gas - troente -> எரிவாயு - ட்ரோன்டே
# fatty liver disease -> கொழுப்பு கல்லீரல் நோய்
# metabolic syndrome -> வளர்சிதை மாற்ற நோய்க்குறி
# fatty liver -> கொழுப்பு கல்லீரல்
# insulin -> இன்சுலின்
# fatty acids -> கொழுப்பு அமிலங்கள்
# liver -> கல்லீரல்
# teins -> டீன்ஸ்
# fatty liver disease -> கொழுப்பு கல்லீரல் நோய்
# fatty acid -> கொழுப்பு அமிலம்
# insulin -> இன்சுலின்
# triacylglycerols -> ட்ரையசில்கிளிசரல்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# chromatography -> குரோமடோகிராபி
# mass spectrometry -> பெருமளவிலான நிறமாலையியல்
# triacylglycerols -> ட்ரையசில்கிளிசரல்கள்
# gas chromatography -> வாயு நிறமூர்த்தம்
# analysis -> பகுப்பாய்வு
# vegetable oils -> தாவர எண்ணெய்கள்
# foods -> உணவுகள்
# triacylglycerols -> ட்ரையசில்கிளிசரல்கள்
# plant oils -> தாவர எண்ணெய்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# triglycerides -> ட்ரைகிளிசரைடுகள்
# gas chromatography -> வாயு நிறமூர்த்தம்
# gas chromatography -> வாயு நிறமூர்த்தம்
# triacylgly -> ட்ரையசில்கி
# cocoa butter -> கோகோ வெண்ணெய்
# milk fat -> பால் கொழுப்பு
# chocolate fat -> சாக்லேட் கொழுப்பு
# coronary heart disease -> இதய நோய்
# analyses -> பகுப்பாய்வு
# observational studies -> அவதானிப்பு ஆய்வுகள்
# - 3 fatty acids -> - 3 கொழுப்பு அமிலங்கள்
# polyphenols -> பாலிபினால்கள்
# oleo science -> ஓலியோ அறிவியல்
# japan oil chemists ’ society -> ஜப்பான் எண்ணெய் வேதியியலாளர்கள் சமூகம்
# screening -> திரையிடல்
# tyrosol -> டைரோசோல்
# including fats and -> கொழுப்புகள் உட்பட மற்றும்
# olive -> ஆலிவ்
# flavor -> சுவை
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# vegetable oils -> தாவர எண்ணெய்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# food chemistry -> உணவு வேதியியல்
# olive oil -> ஆலிவ் எண்ணெய்
# opto - electronics technology -> ஆப்டோ - எலக்ட்ரானிக்ஸ் தொழில்நுட்பம்
# olive -> ஆலிவ்
# raman spectroscopy -> ராமன் ஸ்பெக்ட்ரோஸ்கோபி
# oleic acids -> ஒலிக் அமிலங்கள்
# laser -> லேசர்
# acids -> அமிலங்கள்
# linoleic acids -> லினோலிக் அமிலங்கள்
# density functional -> அடர்த்தி செயல்பாட்டு
# support vector regression -> திசையன் பின்னடைவை ஆதரிக்கவும்
# β - carote -> β - கரோட்
# different volume ratios -> வெவ்வேறு தொகுதி விகிதங்கள்
# laser -> லேசர்
# olive -> ஆலிவ்
# olive pomace -> ஆலிவ் போமஸ்
# sensory defects -> உணர்ச்சி குறைபாடுகள்
# biological phenomena -> உயிரியல் நிகழ்வுகள்
# metric -> மெட்ரிக்
# olive pomace -> ஆலிவ் போமஸ்
# diﬀerent -> di ﬀ erent
# defective oils -> குறைபாடுள்ள எண்ணெய்கள்
# volatile fraction -> கொந்தளிப்பான பின்னம்
# volatiles -> ஆவியாகும்
# volatile -> எளிதில் ஆவியாகிற
# alcohol -> ஆல்கஹால்
# markers -> குறிப்பான்கள்
# olive -> ஆலிவ்
# alcohol -> ஆல்கஹால்
# hydroxy -> ஹைட்ராக்ஸி
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# muddy sediment defect -> சேற்று வண்டல் குறைபாடு
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# vegetable oil -> தாவர எண்ணெய்
# oleic acid -> ஒலீயிக் அமிலம்
# compounds -> கலவைகள்
# volatile organic compounds -> கொந்தளிப்பான கரிம கலவைகள்
# bioactive ph -> பயோஆக்டிவ் பி.எச்
# review -> விமர்சனம்
# olive oil -> ஆலிவ் எண்ணெய்
# phenols -> பினோல்கள்
# fatty liver disease -> கொழுப்பு கல்லீரல் நோய்
# paola priore1 -> பாவோலா பிரியோர் 1
# biology -> உயிரியல்
# fatty liver disease -> கொழுப்பு கல்லீரல் நோய்
# chronic liver disease -> நாள்பட்ட கல்லீரல் நோய்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# hepatic -> கல்லீரல்
# olive oil -> ஆலிவ் எண்ணெய்
# mitochondrial dysfunction -> மைட்டோகாண்ட்ரியல் செயலிழப்பு
# olive oil -> ஆலிவ் எண்ணெய்
# phenols -> பினோல்கள்
# alcoholic fatty liver disease -> ஆல்கஹால் கொழுப்பு கல்லீரல் நோய்
# olive -> ஆலிவ்
# fatty liver disease -> கொழுப்பு கல்லீரல் நோய்
# fatty liver disease -> கொழுப்பு கல்லீரல் நோய்
# chronic -> நாள்பட்ட
# liver disease -> கல்லீரல் நோய்
# liver damage -> கல்லீரல் சேதம்
# hepatitis c virus -> ஹெபடைடிஸ் சி வைரஸ்
# oleo science -> ஓலியோ அறிவியல்
# chemists ’ society -> வேதியியலாளர்கள் சமூகம்
# olive -> ஆலிவ்
# obese -> பருமனான
# oxygen -> ஆக்ஸிஜன்
# ozone -> ஓசோன்
# bacteria -> பாக்டீரியா
# food disinfectants -> உணவு கிருமிநாசினிகள்
# sodium -> சோடியம்
# oleo science -> ஓலியோ அறிவியல்
# japan oil chemists ’ society -> ஜப்பான் எண்ணெய் வேதியியலாளர்கள் சமூகம்
# chemical changes -> வேதியியல் மாற்றங்கள்
# olive -> ஆலிவ்
# gargouri -> கர்கோரி
# labor -> தொழிலாளர்
# olive -> ஆலிவ்
# nutritional -> ஊட்டச்சத்து
# acids -> அமிலங்கள்
# chemical -> வேதியியல்
# tocopher -> டோகோபர்
# polyphenols -> பாலிபினால்கள்
# aromatic hydrocarbon -> நறுமண ஹைட்ரோகார்பன்
# alipha -> அலிபா
# sterols -> ஸ்டெரோல்கள்
# volatile -> எளிதில் ஆவியாகிற
# pounds -> பவுண்டுகள்
# nutrients -> ஊட்டச்சத்துக்கள்
# olive -> ஆலிவ்
# storage -> சேமிப்பு
# cardiovascular diseases -> இருதய நோய்கள்
# oxida -> ஆக்ஸிடா
# inﬂam -> ﬂ am இல்
# extra virgin olive oils -> கூடுதல் கன்னி ஆலிவ் எண்ணெய்கள்
# fraction -> பின்னம்
# olive oil screening -> ஆலிவ் எண்ணெய் ஸ்கிரீனிங்
# proton nmr -> புரோட்டான் என்.எம்.ஆர்
# olive oil screening -> ஆலிவ் எண்ணெய் ஸ்கிரீனிங்
# proton nmr spectra -> புரோட்டான் என்எம்ஆர் ஸ்பெக்ட்ரா
# olive oils -> ஆலிவ் எண்ணெய்கள்
# seed oils -> விதை எண்ணெய்கள்
# principal component analysis -> முதன்மை கூறு பகுப்பாய்வு
# olive oils -> ஆலிவ் எண்ணெய்கள்
# spectra -> ஸ்பெக்ட்ரா
# proton nm -> புரோட்டான் என்.எம்
# virgin -> கன்னி
# olive oil -> ஆலிவ் எண்ணெய்
# organoleptic properties -> ஆர்கனோலெப்டிக் பண்புகள்
# mass spectrometry -> பெருமளவிலான நிறமாலையியல்
# linear discriminant analysis -> நேரியல் பாகுபாடு பகுப்பாய்வு
# vector machine -> திசையன் இயந்திரம்
# least square discrim -> குறைந்த சதுர பாகுபாடு
# orthogonal projection to latent structure - discriminant analysis -> மறைந்திருக்கும் கட்டமைப்பிற்கு ஆர்த்தோகனல் திட்டம் - பாரபட்சமான பகுப்பாய்வு
# counter propagation artificial neural networks -> எதிர் பரப்புதல் செயற்கை நரம்பியல் நெட்வொர்க்குகள்
# self - organizing maps -> சுய - வரைபடங்களை ஒழுங்கமைத்தல்
# investigation -> விசாரணை
# olive -> ஆலிவ்
# diseases -> நோய்கள்
# olive -> ஆலிவ்
# pheno -> பினோ
# compounds -> கலவைகள்
# damage -> சேதம்
# blood hdl - cholesterol -> இரத்த எச்.டி.எல் - கொழுப்பு
# blood pressure -> இரத்த அழுத்தம்
# inﬂammatory properties -> ﬂ ammatation பண்புகளில்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# computer vision chemometrics -> கணினி பார்வை வேதியியல்
# edible oil -> சமையல் எண்ணெய்
# quence of light -> ஒளியின் இடம்
# regression -> பின்னடைவு
# ultraviolet -> புற ஊதா
# vegetable oil -> தாவர எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# edible oil -> சமையல் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# fatty -> கொழுப்பு
# vitamin -> வைட்டமின்
# chemistry -> வேதியியல்
# analytical methods -> பகுப்பாய்வு முறைகள்
# olive oil characterization -> ஆலிவ் எண்ணெய் தன்மை
# classiﬁcation -> கிளாசி ation கேஷன்
# 13c nmr -> 13 சி என்.எம்.ஆர்
# gas chromatography -> வாயு நிறமூர்த்தம்
# nantes -> நாந்தஸ்
# triacylglycerols -> ட்ரையசில்கிளிசரல்கள்
# fatty acids -> கொழுப்பு அமிலங்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# linear regression -> நேரியல் பின்னடைவு
# 13c - in -> 13 சி - இல்
# fatty acids -> கொழுப்பு அமிலங்கள்
# linear -> நேரியல்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# gas chromatography -> வாயு நிறமூர்த்தம்
# olive oil -> ஆலிவ் எண்ணெய்
# analytical variables -> பகுப்பாய்வு மாறிகள்
# fatty acid quan -> கொழுப்பு அமிலம்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# edible oils -> உண்ணக்கூடிய எண்ணெய்கள்
# networks -> நெட்வொர்க்குகள்
# mathematical -> கணிதம்
# brain -> மூளை
# harvest -> அறுவடை
# oil packaging -> எண்ணெய் பேக்கேஜிங்
# molecules review -> மூலக்கூறுகள் மதிப்பாய்வு
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# aging -> வயதான
# epigenetics -> எபிஜெனெடிக்ஸ்
# dna methyl -> டி.என்.ஏ மீதில்
# ion mobility -> அயன் இயக்கம்
# virgin -> கன்னி
# inspection -> ஆய்வு
# class -> வர்க்கம்
# electronic -> மின்னணு
# spectroscopy -> ஸ்பெக்ட்ரோஸ்கோபி
# peroxide -> பெராக்சைடு
# electronic -> மின்னணு
# virgin -> கன்னி
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# virgin olive -> கன்னி ஆலிவ்
# sciences -> அறிவியல்
# extract -> பிரித்தெடுக்கவும்
# and clinic biomedical sciences -> மற்றும் கிளினிக் பயோமெடிக்கல் சயின்சஸ்
# pharmaceutical and nutraceutical -> மருந்து மற்றும் ஊட்டச்சத்து
# blended oils -> கலப்பு எண்ணெய்கள்
# blended -> கலக்கப்பட்டது
# olive -> ஆலிவ்
# atherosclerosis -> பெருந்தமனி தடிப்பு
# ather -> ather
# olive -> ஆலிவ்
# plaque formation -> பிளேக் உருவாக்கம்
# olive -> ஆலிவ்
# fatty acids -> கொழுப்பு அமிலங்கள்
# carrageenan -> கராஜீனன்
# alginate -> ஆல்ஜினேட்
# olive -> ஆலிவ்
# carrageenan -> கராஜீனன்
# alginate -> ஆல்ஜினேட்
# olive oil -> ஆலிவ் எண்ணெய்
# cardiovascular disease -> இருதய நோய்
# cancer -> புற்றுநோய்
# olive oil -> ஆலிவ் எண்ணெய்
# legumes -> பருப்பு வகைகள்
# olive oil -> ஆலிவ் எண்ணெய்
# mediterranean -> மத்திய தரைக்கடல்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# foods -> உணவுகள்
# olive oil -> ஆலிவ் எண்ணெய்
# nut consumption -> நட்டு நுகர்வு
# olive -> ஆலிவ்
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# cancer -> புற்றுநோய்
# olive -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# bitterness -> கசப்பு
# bitterness -> கசப்பு
# olive -> ஆலிவ்
# extraction -> பிரித்தெடுத்தல்
# liquid -> திரவ
# liquid extraction -> திரவ பிரித்தெடுத்தல்
# bitterness -> கசப்பு
# pigments -> நிறமிகள்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# foods -> உணவுகள்
# food che -> உணவு சே
# adult -> வயது வந்தோர்
# plant oils -> தாவர எண்ணெய்கள்
# sterols -> ஸ்டெரோல்கள்
# food che -> உணவு சே
# fraud -> மோசடி
# olive oils -> ஆலிவ் எண்ணெய்கள்
# adult -> வயது வந்தோர்
# spectroscopy -> ஸ்பெக்ட்ரோஸ்கோபி
# compounds -> கலவைகள்
# olive oil -> ஆலிவ் எண்ணெய்
# nutrients -> ஊட்டச்சத்துக்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# extra -> கூடுதல்
# virgin -> கன்னி
# olive oil -> ஆலிவ் எண்ணெய்
# virgin -> கன்னி
# olive oil -> ஆலிவ் எண்ணெய்
# natural products -> இயற்கை தயாரிப்புகள்
# olive -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# mass spectrometry -> பெருமளவிலான நிறமாலையியல்
# phenolic -> பினோலிக்
# triterpenic compounds -> ட்ரைடர்பெனிக் கலவைகள்
# phenolic compounds -> பினோலிக் கலவைகள்
# pinoc -> பினோக்
# hydroxyty -> ஹைட்ராக்ஸி
# secoiridoids -> செகோயிரிடாய்டுகள்
# lignans -> லிக்னான்கள்
# heat map -> வெப்ப வரைபடம்
# sensors -> சென்சார்கள்
# cell - ftir spectroscopy -> செல் - எஃப்.டி.ஐ.ஆர் ஸ்பெக்ட்ரோஸ்கோபி
# oil stability -> எண்ணெய் நிலைத்தன்மை
# hydroperoxides -> ஹைட்ரோபராக்சைடுகள்
# cardiovascular diseases -> இருதய நோய்கள்
# stress -> மன அழுத்தம்
# inflammatory processes -> அழற்சி செயல்முறைகள்
# changes -> மாற்றங்கள்
# oil stability -> எண்ணெய் நிலைத்தன்மை
# hydroperoxides -> ஹைட்ரோபராக்சைடுகள்
# ozone -> ஓசோன்
# bacterial -> பாக்டீரியா
# ozone -> ஓசோன்
# surgi - cal -> சர்ஜி - கால்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# cleaner -> ...error in translation...
# tation -> டேஷன்
# clean -> சுத்தமான
# olive -> ஆலிவ்
# biomass potential -> பயோமாஸ் ஆற்றல்
# heating -> வெப்பமாக்கல்
# energy -> ஆற்றல்
# pastoral -> ஆயர்
# glass -> கண்ணாடி
# olive oil -> ஆலிவ் எண்ணெய்
# energy -> ஆற்றல்
# olive oil -> ஆலிவ் எண்ணெய்
# enzymes -> நொதிகள்
# virgin -> கன்னி
# virgin -> கன்னி
# virgin -> கன்னி
# olive -> ஆலிவ்
# virgin -> கன்னி
# alcohol de -> ஆல்கஹால் டி
# alcohol acetyl -> ஆல்கஹால் அசிடைல்
# dhpea -> dhpea
# dhpea -> dhpea
# food chemistry -> உணவு வேதியியல்
# adult -> வயது வந்தோர்
# olive -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# variable selection -> மாறி தேர்வு
# olive -> ஆலிவ்
# accuracy -> துல்லியம்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# volatile compounds -> கொந்தளிப்பான கலவைகள்
# analytical approaches -> பகுப்பாய்வு அணுகுமுறைகள்
# like activity -> செயல்பாடு போன்றது
# processing markers -> செயலாக்க குறிப்பான்கள்
# milling -> அரைத்தல்
# molecular -> மூலக்கூறு
# conditions -> நிபந்தனைகள்
# malaxation -> மாலாக்ஸேஷன்
# compounds -> கலவைகள்
# voltammetric ﬁngerprinting -> வோல்டாமெட்ரிக் ﬁ ngerprinting
# olive oil -> ஆலிவ் எண்ணெய்
# inorganic and analytical chemistry -> கனிம மற்றும் பகுப்பாய்வு வேதியியல்
# greece -> கிரீஸ்
# voltammetric -> வோல்டாமெட்ரிக்
# ﬁngerprint -> ﬁ ngerprint
# dif - ferentiation -> வேறுபாடு
# olive -> ஆலிவ்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# voltammetry -> வால்டமெட்ரி
# principal component analysis -> முதன்மை கூறு பகுப்பாய்வு
# voltammetric ﬁngerprinting -> வோல்டாமெட்ரிக் ﬁ ngerprinting
# chemometric -> வேதியியல்
# olive po -> ஆலிவ் போ
# cyclic voltammog -> சுழற்சி வால்டமோகிராம்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olive pomace oils -> ஆலிவ் போமஸ் எண்ணெய்கள்
# seed oils -> விதை எண்ணெய்கள்
# liclo4 -> liclo4
# electrolyte -> எலக்ட்ரோலைட்
# cyclic voltammetry -> சுழற்சி வால்டமெட்ரி
# extracts -> பிரித்தெடுத்தல்
# cyclic vol - tammogram -> சுழற்சி வால்டமோகிராம்
# square -> சதுரம்
# analysis -> பகுப்பாய்வு
# mineral oil -> கனிம எண்ணெய்
# leaks -> கசிவுகள்
# chrom -> குரோம்
# platform -> நடைமேடை
# oleoca -> ஓலியோகா
# oleacein -> ஓலாசின்
# olive oil -> ஆலிவ் எண்ணெய்
# extra virgin olive oils -> கூடுதல் கன்னி ஆலிவ் எண்ணெய்கள்
# oleuropein -> ஒலூரோபின்
# ligstroside aglycon -> லிக்ஸ்ட்ரோசைடு அக்லிகான்
# oleoca -> ஓலியோகா
# olive oil -> ஆலிவ் எண்ணெய்
# aging -> வயதான
# temperature -> வெப்ப நிலை
# olive oil -> ஆலிவ் எண்ணெய்
# cause -> காரணம்
# food packaging -> உணவு பேக்கேஜிங்
# recherche et d ’ analyse physico - chimique -> ரெச்செர்ச் மற்றும் டி ’பகுப்பாய்வு இயற்பியல் - சிமிக்
# packaging -> பேக்கேஜிங்
# higher edu - cation and -> உயர் கல்வி மற்றும்
# olive -> ஆலிவ்
# exponential -> அதிவேக
# adult -> வயது வந்தோர்
# corn oil -> சோள எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# corn oil -> சோள எண்ணெய்
# raman spectroscopy -> ராமன் ஸ்பெக்ட்ரோஸ்கோபி
# exponential -> அதிவேக
# intensity -> தீவிரம்
# raman spectroscopy -> ராமன் ஸ்பெக்ட்ரோஸ்கோபி
# changes -> மாற்றங்கள்
# fraction -> பின்னம்
# raman spectroscopy -> ராமன் ஸ்பெக்ட்ரோஸ்கோபி
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# nigel -> நைகல்
# sativa oil -> சாடிவா எண்ணெய்
# hepatotoxicity -> ஹெபடோடாக்சிசிட்டி
# liver -> கல்லீரல்
# hepatotherapeutic agents -> ஹெபடோ சிகிச்சை முகவர்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# liver damage -> கல்லீரல் சேதம்
# injected -> செலுத்தப்பட்டது
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# total biliru -> மொத்த பிலிரூபின்
# lipid peroxide -> லிப்பிட் பெராக்சைடு
# total -> மொத்தம்
# interleuki -> இன்டர்லூகின்
# total protein -> மொத்த புரதம்
# albumin an -> ஆல்புமின் ஒரு
# histology -> வரலாறு
# inflammation -> அழற்சி
# damage -> சேதம்
# olive oil -> ஆலிவ் எண்ணெய்
# tests -> சோதனைகள்
# liver -> கல்லீரல்
# olive -> ஆலிவ்
# inflammatory in -> அழற்சி
# olive -> ஆலிவ்
# sativa oil -> சாடிவா எண்ணெய்
# nigel -> நைகல்
# olive -> ஆலிவ்
# che - mometric -> சே - மாமெட்ரிக்
# ft - nir -> ft - nir
# ir spectroscopy -> ஐஆர் ஸ்பெக்ட்ரோஸ்கோபி
# fish fillet -> மீன் ஃபில்லட்
# food science -> உணவு அறிவியல்
# acids -> அமிலங்கள்
# olive -> ஆலிவ்
# nanostructures -> நானோ கட்டமைப்புகள்
# fatty acids -> கொழுப்பு அமிலங்கள்
# delivery for - mulation -> விநியோக உருவாக்கம்
# virgin olive -> கன்னி ஆலிவ்
# adul - teration -> கலப்படம்
# computers -> கணினிகள்
# electronics in agriculture -> விவசாயத்தில் மின்னணுவியல்
# oleo science -> ஓலியோ அறிவியல்
# japan -> ஜப்பான்
# oil chemists ’ society -> எண்ணெய் வேதியியலாளர்கள் சமூகம்
# oil characteristics -> எண்ணெய் பண்புகள்
# olive varieties -> ஆலிவ் வகைகள்
# maria lo -> மரியா லோ
# olive harvest -> ஆலிவ் அறுவடை
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# phenols -> பினோல்கள்
# sterols -> ஸ்டெரோல்கள்
# sensory profile -> உணர்ச்சி சுயவிவரம்
# endoscopy -> எண்டோஸ்கோபி
# imaging -> இமேஜிங்
# bowel -> குடல்
# serum catestatin -> சீரம் கேடெஸ்டாடின்
# arterial stiffness parameters -> தமனி விறைப்பு அளவுருக்கள்
# matrix gla protein -> மேட்ரிக்ஸ் கிளா புரதம்
# microarchitecture -> மைக்ரோஆர்கிடெக்சர்
# olive oil -> ஆலிவ் எண்ணெய்
# model -> மாதிரி
# dexame -> டெக்ஸேம்
# histopathological changes -> ஹிஸ்டோபோதாலஜிகல் மாற்றங்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# bone mineral -> எலும்பு தாது
# terpenoids -> டெர்பெனாய்டுகள்
# compounds -> கலவைகள்
# heads -> தலைகள்
# micro -> மைக்ரோ
# changes -> மாற்றங்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# volatile organic compounds -> கொந்தளிப்பான கரிம கலவைகள்
# status -> நிலை
# light environment -> ஒளி சூழல்
# analysis -> பகுப்பாய்வு
# approaches -> அணுகுமுறைகள்
# liquid chromatography -> திரவ நிறமூர்த்தம்
# mass spectrometry -> பெருமளவிலான நிறமாலையியல்
# aroma -> நறுமணம்
# virgin olive oils -> கன்னி ஆலிவ் எண்ணெய்கள்
# fatty acids -> கொழுப்பு அமிலங்கள்
# olive -> ஆலிவ்
# cultivar -> சாகுபடி
# ingredients -> பொருட்கள்
# polar -> துருவ
# olive oils -> ஆலிவ் எண்ணெய்கள்
# platelet hyper -> பிளேட்லெட் ஹைப்பர்
# obesity -> உடல் பருமன்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# plate -> தட்டு
# platelet activation -> பிளேட்லெட் செயல்படுத்தல்
# diet composition -> உணவு கலவை
# olive oil -> ஆலிவ் எண்ணெய்
# platelet -> பிளேட்லெட்
# selectin -> தேர்ந்தெடுக்கப்பட்ட
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# platelet activation -> பிளேட்லெட் செயல்படுத்தல்
# plate -> தட்டு
# olive -> ஆலிவ்
# analyses -> பகுப்பாய்வு
# agricultural census -> விவசாய மக்கள் தொகை கணக்கெடுப்பு
# cultural statistics -> கலாச்சார புள்ளிவிவரங்கள்
# olive -> ஆலிவ்
# palestinian olive -> பாலஸ்தீனிய ஆலிவ்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# hydrolyzable phenolic compounds -> ஹைட்ரோலைசபிள் பினோலிக் கலவைகள்
# network -> வலைப்பின்னல்
# classiﬁcation -> கிளாசி ation கேஷன்
# edible oils -> உண்ணக்கூடிய எண்ணெய்கள்
# thermal analysis -> வெப்ப பகுப்பாய்வு
# calorimetry -> கலோரிமெட்ரி
# near infrared spectroscopy -> அகச்சிவப்பு ஸ்பெக்ட்ரோஸ்கோபி அருகே
# olive fruit and oil -> ஆலிவ் பழம் மற்றும் எண்ணெய்
# near infrared spectroscopy -> அகச்சிவப்பு ஸ்பெக்ட்ரோஸ்கோபி அருகே
# class -> வர்க்கம்
# pyrolysis -> பைரோலிசிஸ்
# fertilizing effect -> உரமிடும் விளைவு
# olive mill waste -> ஆலிவ் மில் கழிவு
# compost -> உரம்
# biodegradation -> மக்கும் தன்மை
# sensory -> உணர்ச்சி
# - ation -> - ation
# virgin olive -> கன்னி ஆலிவ்
# neural network -> நரம்பியல் நெட்வொர்க்
# agriculture -> வேளாண்மை
# olive oil -> ஆலிவ் எண்ணெய்
# mapping -> விவரணையாக்கம்
# proton transfer reaction -> புரோட்டான் பரிமாற்ற எதிர்வினை
# mass spectrometry -> பெருமளவிலான நிறமாலையியல்
# alteration -> மாற்றுதல்
# food chemistry -> உணவு வேதியியல்
# sciences -> அறிவியல்
# electrochemical -> மின் வேதியியல்
# biosensors -> பயோசென்சர்கள்
# electrochemical sensors -> மின் வேதியியல் சென்சார்கள்
# biosen -> பயோசென்
# arrays -> வரிசைகள்
# sensory proﬁle -> சென்சரி புரோ ﬁ லெ
# phenolic compounds -> பினோலிக் கலவைகள்
# olive -> ஆலிவ்
# time kill curves -> நேரம் கில் வளைவுகள்
# olive -> ஆலிவ்
# strain inhibition -> திரிபு தடுப்பு
# olive -> ஆலிவ்
# biofilm -> பயோஃபில்ம்
# olive -> ஆலிவ்
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# western -> மேற்கு
# chloral hydrate -> குளோரல் ஹைட்ரேட்
# liver -> கல்லீரல்
# weight -> எடை
# weight -> எடை
# extra - virgin - olive oils -> கூடுதல் - கன்னி - ஆலிவ் எண்ணெய்கள்
# skin manifestation -> தோல் வெளிப்பாடு
# toxic syndrome -> நச்சு நோய்க்குறி
# dietetic products -> உணவுப் பொருட்கள்
# saturated fatty acids -> நிறைவுற்ற கொழுப்பு அமிலங்கள்
# ldl - cholesterol -> எல்.டி.எல் - கொழுப்பு
# dietetic products -> உணவுப் பொருட்கள்
# edible fat -> உண்ணக்கூடிய கொழுப்பு
# european food -> ஐரோப்பிய உணவு
# authority -> அதிகாரம்
# olive -> ஆலிவ்
# secoir -> செகோயர்
# secoir -> செகோயர்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# samples -> மாதிரிகள்
# olive -> ஆலிவ்
# metabolism -> வளர்சிதை மாற்றம்
# phenols -> பினோல்கள்
# compounds -> கலவைகள்
# biological rhythms -> உயிரியல் தாளங்கள்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# composition -> கலவை
# virgin olive oils -> கன்னி ஆலிவ் எண்ணெய்கள்
# chemist -> வேதியியலாளர்
# olive oil -> ஆலிவ் எண்ணெய்
# calib -> காலிப்
# analysis -> பகுப்பாய்வு
# authentication -> அங்கீகார
# olive -> ஆலிவ்
# determination -> உறுதியை
# olive -> ஆலிவ்
# spectrometer -> ஸ்பெக்ட்ரோமீட்டர்
# trans fat -> டிரான்ஸ் கொழுப்பு
# sugar -> சர்க்கரை
# food chemistry -> உணவு வேதியியல்
# mineral -> கனிமம்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# mineral -> கனிமம்
# olive -> ஆலிவ்
# leaks -> கசிவுகள்
# liquid chromatography -> திரவ நிறமூர்த்தம்
# chromatography -> குரோமடோகிராபி
# ionization detection -> அயனியாக்கம் கண்டறிதல்
# gas chromatographic platform -> வாயு குரோமடோகிராஃபிக் தளம்
# harvesting -> அறுவடை
# mineral oil hydro -> கனிம எண்ணெய் ஹைட்ரோ
# petroleum distillation products -> பெட்ரோலிய வடிகட்டுதல் தயாரிப்புகள்
# alcoholic -> ஆல்கஹால்
# fatty liver disease -> கொழுப்பு கல்லீரல் நோய்
# carbohydrates -> கார்போஹைட்ரேட்டுகள்
# fatty liver disease -> கொழுப்பு கல்லீரல் நோய்
# olive oil -> ஆலிவ் எண்ணெய்
# nitro - fatty acids -> நைட்ரோ - கொழுப்பு அமிலங்கள்
# alcoholic fatty liver disease -> ஆல்கஹால் கொழுப்பு கல்லீரல் நோய்
# metabolic syndrome -> வளர்சிதை மாற்ற நோய்க்குறி
# intervention -> தலையீடு
# cooking -> சமையல்
# fatty acids -> கொழுப்பு அமிலங்கள்
# control -> கட்டுப்பாடு
# fatty liver -> கொழுப்பு கல்லீரல்
# diabetes -> நீரிழிவு நோய்
# cardiovascular -> இருதய
# coronary artery disease -> கரோனரி தமனி நோய்
# inflammation -> அழற்சி
# ather -> ather
# nutrients review -> ஊட்டச்சத்துக்கள் மதிப்பாய்வு
# olive oil -> ஆலிவ் எண்ணெய்
# color -> நிறம்
# cancer -> புற்றுநோய்
# colorectal cancer -> பெருங்குடல் புற்றுநோய்
# mediterranean -> மத்திய தரைக்கடல்
# color -> நிறம்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# supplements -> கூடுதல்
# cancer -> புற்றுநோய்
# sensors -> சென்சார்கள்
# olive -> ஆலிவ்
# evaluation -> மதிப்பீடு
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# different -> வெவ்வேறு
# gelators -> ஜெலேட்டர்கள்
# oleogelation -> oleogelation
# mechanisms -> வழிமுறைகள்
# food hydro -> உணவு ஹைட்ரோ
# radical -> தீவிரமான
# - chemical parameters -> - வேதியியல் அளவுருக்கள்
# infrared spectroscopy -> அகச்சிவப்பு ஸ்பெக்ட்ரோஸ்கோபி
# parameters -> அளவுருக்கள்
# free acidity -> இலவச அமிலத்தன்மை
# peroxide value -> பெராக்சைடு மதிப்பு
# errors -> பிழைகள்
# photooxidation -> ஒளிச்சேர்க்கை
# olive -> ஆலிவ்
# carotenoids -> கரோட்டினாய்டுகள்
# chlorophylls -> குளோரோபில்ஸ்
# virgin -> கன்னி
# effect -> விளைவு
# virgin -> கன்னி
# pigments -> நிறமிகள்
# virgin -> கன்னி
# virgin -> கன்னி
# virgin -> கன்னி
# stability -> ஸ்திரத்தன்மை
# olive oil council -> ஆலிவ் ஆயில் கவுன்சில்
# olive oil balance -> ஆலிவ் எண்ணெய் இருப்பு
# market -> சந்தை
# olive -> ஆலிவ்
# trade -> வர்த்தகம்
# olive oil -> ஆலிவ் எண்ணெய்
# olive - pomac -> ஆலிவ் - போமாக்
# charac - teristic -> பண்பு
# olive -> ஆலிவ்
# meth - ods -> மெத் - ஓட்ஸ்
# spectroscopy -> ஸ்பெக்ட்ரோஸ்கோபி
# spanish -> ஸ்பானிஷ்
# near - infrared reﬂectance spectroscopic analysis -> அருகில் - அகச்சிவப்பு மறு ﬂ எக்டன்ஸ் ஸ்பெக்ட்ரோஸ்கோபிக் பகுப்பாய்வு
# food che -> உணவு சே
# oil acc -> எண்ணெய் அக்
# abstract fibroblasts -> சுருக்க ஃபைப்ரோபிளாஸ்ட்கள்
# tissue -> திசு
# ccd - -> சி.சி.டி -
# human fibroblast -> மனித ஃபைப்ரோபிளாஸ்ட்
# cell proliferation -> செல் பெருக்கம்
# actin -> ஆக்டின்
# sensor -> சென்சார்
# evaluation -> மதிப்பீடு
# techniques -> நுட்பங்கள்
# olive -> ஆலிவ்
# properties -> பண்புகள்
# chilling -> குளிர்வித்தல்
# freezing -> உறைபனி
# injuries -> காயங்கள்
# olive -> ஆலிவ்
# harvested -> அறுவடை
# freezing condition -> உறைபனி நிலை
# extraction -> பிரித்தெடுத்தல்
# common analyses -> பொதுவான பகுப்பாய்வு
# total ph -> மொத்த பி.எச்
# storage -> சேமிப்பு
# extracted -> பிரித்தெடுக்கப்பட்டது
# effect -> விளைவு
# research -> ஆராய்ச்சி
# olive oil -> ஆலிவ் எண்ணெய்
# deleterious -> தீங்கு
# olive -> ஆலிவ்
# conventional -> வழக்கமான
# dexame -> டெக்ஸேம்
# serum -> சீரம்
# histopathological changes -> ஹிஸ்டோபோதாலஜிகல் மாற்றங்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# bone thickness -> எலும்பு தடிமன்
# olive oil -> ஆலிவ் எண்ணெய்
# triacylglycerol hydroperoxide -> ட்ரையசில்கிளிசரால் ஹைட்ரோபெராக்சைடு
# triacylglycerol hydroperoxide -> ட்ரையசில்கிளிசரால் ஹைட்ரோபெராக்சைடு
# cardiovascular disease -> இருதய நோய்
# chronic diseases -> நாட்பட்ட நோய்கள்
# removing -> நீக்குதல்
# replacement -> மாற்று
# gel structures -> ஜெல் கட்டமைப்புகள்
# intensity -> தீவிரம்
# raman spectroscopy -> ராமன் ஸ்பெக்ட்ரோஸ்கோபி
# spectroscopy -> ஸ்பெக்ட்ரோஸ்கோபி
# dementia -> டிமென்ஷியா
# stress -> மன அழுத்தம்
# dementia -> டிமென்ஷியா
# dementia -> டிமென்ஷியா
# alzheimer disease -> அல்சைமர் நோய்
# parkinson ’ s disease -> பார்கின்சன் நோய்
# diseases -> நோய்கள்
# parkinson disease -> பார்கின்சன் நோய்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# products -> தயாரிப்புகள்
# olive oil -> ஆலிவ் எண்ணெய்
# products -> தயாரிப்புகள்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# tocopherols -> டோகோபெரோல்கள்
# olive -> ஆலிவ்
# processing systems -> செயலாக்க அமைப்புகள்
# oleo science -> ஓலியோ அறிவியல்
# mill olive -> மில் ஆலிவ்
# aceites -> ACITES
# phenolic compounds -> பினோலிக் கலவைகள்
# american oil chemists ’ society -> அமெரிக்க எண்ணெய் வேதியியலாளர்கள் சமூகம்
# bioactive compounds -> பயோஆக்டிவ் கலவைகள்
# virgin -> கன்னி
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# food research -> உணவு ஆராய்ச்சி
# chemical properties -> வேதியியல் பண்புகள்
# fadak -> ஃபடக்
# gilvan -> கில்வன்
# aceites -> ACITES
# olive varieties -> ஆலிவ் வகைகள்
# agricultural science and technology -> விவசாய அறிவியல் மற்றும் தொழில்நுட்பம்
# climate envelope models -> காலநிலை உறை மாதிரிகள்
# change -> மாற்றம்
# global -> உலகளாவிய
# bitterness -> கசப்பு
# bitterness -> கசப்பு
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# extraction -> பிரித்தெடுத்தல்
# extraction -> பிரித்தெடுத்தல்
# bitterness -> கசப்பு
# food chemistry -> உணவு வேதியியல்
# authentication -> அங்கீகார
# virgin olive -> கன்னி ஆலிவ்
# hydrocarbon -> ஹைட்ரோகார்பன்
# food chemistry -> உணவு வேதியியல்
# metabolomics -> வளர்சிதை மாற்ற
# olive -> ஆலிவ்
# adult -> வயது வந்தோர்
# study -> ஆய்வு
# olive oils -> ஆலிவ் எண்ணெய்கள்
# analytical -> பகுப்பாய்வு
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# olive po -> ஆலிவ் போ
# adult -> வயது வந்தோர்
# trapped ion mobility spectrometry -> சிக்கிய அயன் மொபிலிட்டி ஸ்பெக்ட்ரோமெட்ரி
# liquid chromatography -> திரவ நிறமூர்த்தம்
# mass spectrometry -> பெருமளவிலான நிறமாலையியல்
# metabolomics -> வளர்சிதை மாற்ற
# authenticity -> நம்பகத்தன்மை
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olive pomace oils -> ஆலிவ் போமஸ் எண்ணெய்கள்
# adult -> வயது வந்தோர்
# breast -> மார்பகம்
# restriction -> கட்டுப்பாடு
# breast -> மார்பகம்
# dietary fat -> உணவு கொழுப்பு
# cancer -> புற்றுநோய்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# extraction -> பிரித்தெடுத்தல்
# bioprocess -> பயோபிரசஸ்
# olive phenolic compounds -> ஆலிவ் பினோலிக் கலவைகள்
# conditioning -> கண்டிஷனிங்
# olive paste -> ஆலிவ் பேஸ்ட்
# ultrasounds -> அல்ட்ராசவுண்ட்ஸ்
# methodology -> முறை
# volatile compounds -> கொந்தளிப்பான கலவைகள்
# cultivar -> சாகுபடி
# ultrasound -> அல்ட்ராசவுண்ட்
# ultrasonic -> மீயொலி
# hydro -> ஹைட்ரோ
# virgin -> கன்னி
# chemotherapy -> கீமோதெரபி
# toxicity -> நச்சுத்தன்மை
# olive oil polyph -> ஆலிவ் ஆயில் பாலிஃப்
# hydroxytyrosol ( -> ஹைட்ராக்ஸிடிரோசோல் (
# tyrosol -> டைரோசோல்
# oleuropein -> ஒலூரோபின்
# oleacein -> ஓலாசின்
# fatty liver disease -> கொழுப்பு கல்லீரல் நோய்
# chronic -> நாள்பட்ட
# liver disease -> கல்லீரல் நோய்
# olive -> ஆலிவ்
# animal models -> விலங்கு மாதிரிகள்
# olive oil -> ஆலிவ் எண்ணெய்
# mitochondrial dysfunction -> மைட்டோகாண்ட்ரியல் செயலிழப்பு
# mass spectrometry profiling -> வெகுஜன நிறமாலை விவரக்குறிப்பு
# olive oil -> ஆலிவ் எண்ணெய்
# analytical -> பகுப்பாய்வு
# olive oil -> ஆலிவ் எண்ணெய்
# mass spectrometry chemometrics -> வெகுஜன நிறமாலை வேதியியல்
# molecular profiling -> மூலக்கூறு விவரக்குறிப்பு
# olive oil -> ஆலிவ் எண்ணெய்
# fraction -> பின்னம்
# mass spectrometry -> பெருமளவிலான நிறமாலையியல்
# mass spectrometry experiments -> வெகுஜன நிறமாலை சோதனைகள்
# olive oil -> ஆலிவ் எண்ணெய்
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# trans fatty acids -> டிரான்ஸ் கொழுப்பு அமிலங்கள்
# retrotransposon dna -> ரெட்ரோட்ரான்ஸ்போசன் டி.என்.ஏ.
# olive oil -> ஆலிவ் எண்ணெய்
# trans fatty acids -> டிரான்ஸ் கொழுப்பு அமிலங்கள்
# retrotransposon -> ரெட்ரோட்ரான்ஸ்போசன்
# environmental carcinogen model -> சுற்றுச்சூழல் புற்றுநோய் மாதிரி
# olive oil -> ஆலிவ் எண்ணெய்
# pheno -> பினோ
# alzheimer ’ s -> அல்சைமர்
# parkinson ’ s diseases -> பார்கின்சனின் நோய்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# parkinson ’ -> பார்கின்சன்
# alzheimer -> முதுமறதி
# alzheimer ’ -> முதுமறதி '
# disease -> நோய்
# parkinson ’ -> பார்கின்சன்
# disease -> நோய்
# stroke -> பக்கவாதம்
# spinal cord injury -> முதுகெலும்பு காயம்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olive pom - ace oils -> ஆலிவ் போமஸ் எண்ணெய்
# olive - residue oil -> ...error in translation...
# tyrosol -> டைரோசோல்
# evoo adulteration -> EVOO கலப்படம்
# olive oil -> ஆலிவ் எண்ணெய்
# olive - pomac -> ஆலிவ் - போமாக்
# spectroscopy -> ஸ்பெக்ட்ரோஸ்கோபி
# index -> குறியீட்டு
# nutrients -> ஊட்டச்சத்துக்கள்
# functional bioactives -> செயல்பாட்டு பயோஆக்டிவ்ஸ்
# edible oil -> சமையல் எண்ணெய்
# compounds -> கலவைகள்
# organ -> உறுப்பு
# hydrogel -> ஹைட்ரஜல்
# cosmetic -> ஒப்பனை
# contrast phase microscopy -> மாறுபட்ட கட்ட நுண்ணோக்கி
# electric conductivity -> மின்சார கடத்துத்திறன்
# organogel -> ஆர்கனோஜெல்
# microstructural change -> நுண் கட்டமைப்பு மாற்றம்
# matrix - in - matrix structure -> மேட்ரிக்ஸ் - இல் - மேட்ரிக்ஸ் அமைப்பு
# standards -> தரநிலைகள்
# olive oil -> ஆலிவ் எண்ணெய்
# aroma -> நறுமணம்
# volatiles -> ஆவியாகும்
# perception -> கருத்து
# olive -> ஆலிவ்
# fraction -> பின்னம்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olive -> ஆலிவ்
# dietetic products -> உணவுப் பொருட்கள்
# nutrition and all -> ஊட்டச்சத்து மற்றும் அனைத்தும்
# polyph -> பாலிப்
# damage -> சேதம்
# blood -> இரத்தம்
# normal -> சாதாரண
# blood pressure -> இரத்த அழுத்தம்
# olive oil -> ஆலிவ் எண்ணெய்
# sensor -> சென்சார்
# evaluation -> மதிப்பீடு
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# absorption spectroscopy -> உறிஞ்சுதல் ஸ்பெக்ட்ரோஸ்கோபி
# authentication -> அங்கீகார
# vegetable oils -> தாவர எண்ணெய்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# electrochemical sensor -> மின் வேதியியல் சென்சார்
# hydroper - oxides -> ஹைட்ரோப்பர் - ஆக்சைடுகள்
# prussian blue -> பிரஷ்யன் நீலம்
# sensors -> சென்சார்கள்
# actuators -> ஆக்சுவேட்டர்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# phenolic characterization -> பினோலிக் தன்மை
# geographical classiﬁcation -> புவியியல் கிளாசி ation கேஷன்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# electrospray ioni -> எலக்ட்ரோஸ்ப்ரே அயனி
# mass spectrometry -> பெருமளவிலான நிறமாலையியல்
# mass spectrometry -> பெருமளவிலான நிறமாலையியல்
# adult -> வயது வந்தோர்
# olive -> ஆலிவ்
# carbon stable isotopes -> கார்பன் நிலையான ஐசோடோப்புகள்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# uv led -> புற ஊதா எல்.ஈ.டி
# olive -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# methyl -> மீதில்
# dna methylation -> டி.என்.ஏ மெத்திலேஷன்
# tumor -> கட்டி
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# trans fatty -> டிரான்ஸ் கொழுப்பு
# acids -> அமிலங்கள்
# spleen -> மண்ணீரல்
# environmental -> சுற்றுச்சூழல்
# 12 - dimethylb -> 12 - டைமெதில்ப்
# dna methyltra -> டி.என்.ஏ மெத்தில்ட்ரா
# inflammatory -> அழற்சி
# fourier transform raman spectra -> ஃபோரியர் ராமன் ஸ்பெக்ட்ராவை மாற்றவும்
# unsaponifiable matter -> விதிக்கப்பட முடியாத விஷயம்
# edible oils -> உண்ணக்கூடிய எண்ணெய்கள்
# bottle -> பாட்டில்
# raman analysis -> ராமன் பகுப்பாய்வு
# free fatty acid content -> இலவச கொழுப்பு அமில உள்ளடக்கம்
# infrared spectrometry -> அகச்சிவப்பு நிறமாலை
# liquid chromatography -> திரவ நிறமூர்த்தம்
# triacylglycer -> ட்ரையசில்கிளிசரால்
# free fatty acids -> இலவச கொழுப்பு அமிலங்கள்
# β - carotene -> β - கரோட்டின்
# oleic acids -> ஒலிக் அமிலங்கள்
# carote -> கரோட்
# raman -> ராமன்
# oleic acids -> ஒலிக் அமிலங்கள்
# linoleic acids -> லினோலிக் அமிலங்கள்
# density functional theory -> அடர்த்தி செயல்பாட்டுக் கோட்பாடு
# vector regression -> திசையன் பின்னடைவு
# carotene -> கரோட்டின்
# volume ratios -> தொகுதி விகிதங்கள்
# ultrasound machine -> அல்ட்ராசவுண்ட் இயந்திரம்
# ultrasound -> அல்ட்ராசவுண்ட்
# ultrasound -> அல்ட்ராசவுண்ட்
# olive -> ஆலிவ்
# ultrasound -> அல்ட்ராசவுண்ட்
# ultrasound -> அல்ட்ராசவுண்ட்
# pheno -> பினோ
# compounds -> கலவைகள்
# antiox -> ஆன்டிஆக்ஸ்
# spectroscopy -> ஸ்பெக்ட்ரோஸ்கோபி
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olive -> ஆலிவ்
# nuclear magnetic resonance -> அணு காந்த அதிர்வு
# olive oils -> ஆலிவ் எண்ணெய்கள்
# oleuropein -> ஒலூரோபின்
# elenolide -> எலினோலைடு
# olive -> ஆலிவ்
# fruits -> பழங்கள்
# elenolide -> எலினோலைடு
# characterized -> வகைப்படுத்தப்பட்டது
# quantitative measurement -> அளவு அளவீட்டு
# olive -> ஆலிவ்
# elenolide -> எலினோலைடு
# elenolide -> எலினோலைடு
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# trials -> சோதனைகள்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# nutrients review -> ஊட்டச்சத்துக்கள் மதிப்பாய்வு
# parent -> பெற்றோர்
# nutrition -> ஊட்டச்சத்து
# acids -> அமிலங்கள்
# beneﬁts -> ben ﬁ ts
# olive -> ஆலிவ்
# sensory defects -> உணர்ச்சி குறைபாடுகள்
# techniques -> நுட்பங்கள்
# multivariate analysis -> பன்முக பகுப்பாய்வு
# analytical chemistry -> பகுப்பாய்வு வேதியியல்
# chemometric -> வேதியியல்
# , qualimetrics and nanosensors -> , குவாலிமெட்ரிக்ஸ் மற்றும் நானோசென்சர்கள்
# analytical chemistry -> பகுப்பாய்வு வேதியியல்
# virgin olive -> கன்னி ஆலிவ்
# virgin olive -> கன்னி ஆலிவ்
# mass spectrometry -> பெருமளவிலான நிறமாலையியல்
# infrared spectroscopy -> அகச்சிவப்பு ஸ்பெக்ட்ரோஸ்கோபி
# – vis spectrophotometry -> - விஸ் ஸ்பெக்ட்ரோஃபோட்டோமெட்ரி
# data fusion -> தரவு இணைவு
# multivar -> மல்டிவார்
# analysis -> பகுப்பாய்வு
# least squares - discriminant analysis -> குறைந்த சதுரங்கள் - பாரபட்சமான பகுப்பாய்வு
# sensory analysis -> உணர்ச்சி பகுப்பாய்வு
# headspace -> ஹெட்ஸ்பேஸ்
# mass spectrometry -> பெருமளவிலான நிறமாலையியல்
# mid - infrared spectroscopy -> நடுப்பகுதி - அகச்சிவப்பு ஸ்பெக்ட்ரோஸ்கோபி
# uv – visible spectrophotometry -> புற ஊதா - புலப்படும் ஸ்பெக்ட்ரோஃபோட்டோமெட்ரி
# virgin olive -> கன்னி ஆலிவ்
# general model -> பொது மாதிரி
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# data fusion -> தரவு இணைவு
# mass spectrometric methods -> வெகுஜன நிறமாலை முறைகள்
# olive -> ஆலிவ்
# authenticity -> நம்பகத்தன்மை
# greece -> கிரீஸ்
# ﬁngerprint -> ﬁ ngerprint
# olive -> ஆலிவ்
# chemometric techniques -> வேதியியல் நுட்பங்கள்
# foodomics -> ஃபுடோமிக்ஸ்
# chemical proﬁling authenticity -> வேதியியல் சார்பு நம்பகத்தன்மை
# organ -> உறுப்பு
# analytical method -> பகுப்பாய்வு முறை
# mass spectrometry -> பெருமளவிலான நிறமாலையியல்
# principal component analysis -> முதன்மை கூறு பகுப்பாய்வு
# paste -> ஒட்டவும்
# microwave treatment -> மைக்ரோவேவ் சிகிச்சை
# malaxation of olive paste -> ஆலிவ் பேஸ்டின் மாலாக்ஸேஷன்
# thermal conditioning -> வெப்ப கண்டிஷனிங்
# olive -> ஆலிவ்
# mechanical extraction -> இயந்திர பிரித்தெடுத்தல்
# cooling treatment -> குளிரூட்டும் சிகிச்சை
# olive oil extraction -> ஆலிவ் எண்ணெய் பிரித்தெடுத்தல்
# ultrasound -> அல்ட்ராசவுண்ட்
# microwave -> மைக்ரோவேவ்
# heat exchange -> வெப்ப பரிமாற்றம்
# olive oil -> ஆலிவ் எண்ணெய்
# experimental models -> சோதனை மாதிரிகள்
# olive oil -> ஆலிவ் எண்ணெய்
# liver -> கல்லீரல்
# healthy -> ஆரோக்கியமான
# state -> நிலை
# hepatic diseases -> கல்லீரல் நோய்கள்
# olive -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# blood -> இரத்தம்
# collected -> சேகரிக்கப்பட்டது
# serum biochemical components -> சீரம் உயிர்வேதியியல் கூறுகள்
# histological analysis -> வரலாற்று பகுப்பாய்வு
# sudan iii stain -> சூடான் III கறை
# transcript expression -> டிரான்ஸ்கிரிப்ட் வெளிப்பாடு
# hepatic -> கல்லீரல்
# genes -> மரபணு
# liver -> கல்லீரல்
# messenger rna expression analyses -> மெசஞ்சர் ஆர்.என்.ஏ வெளிப்பாடு பகுப்பாய்வு
# expression -> வெளிப்பாடு
# fatty acid synthesis -> கொழுப்பு அமில தொகுப்பு
# liver impairment -> கல்லீரல் குறைபாடு
# olive -> ஆலிவ்
# wavelengths -> அலைநீளங்கள்
# uv led -> புற ஊதா எல்.ஈ.டி
# olive -> ஆலிவ்
# production -> உற்பத்தி
# antioxidants -> ஆக்ஸிஜனேற்றிகள்
# olive oil extraction -> ஆலிவ் எண்ணெய் பிரித்தெடுத்தல்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# food che -> உணவு சே
# olive -> ஆலிவ்
# foods -> உணவுகள்
# olive -> ஆலிவ்
# treatment -> சிகிச்சை
# quantum chemical -> குவாண்டம் வேதியியல்
# functional theory -> செயல்பாட்டு கோட்பாடு
# chemistry -> வேதியியல்
# correlation -> தொடர்பு
# noise reduction -> சத்தம் குறைப்பு
# speech processing -> பேச்சு செயலாக்கம்
# raman spectroscopy -> ராமன் ஸ்பெக்ட்ரோஸ்கோபி
# machine - learning -> இயந்திர வழி கற்றல்
# edible oils -> உண்ணக்கூடிய எண்ணெய்கள்
# raman spectroscopy -> ராமன் ஸ்பெக்ட்ரோஸ்கோபி
# imaging -> இமேஜிங்
# raman spectroscopy -> ராமன் ஸ்பெக்ட்ரோஸ்கோபி
# exponential -> அதிவேக
# adult -> வயது வந்தோர்
# micro -> மைக்ரோ
# production -> உற்பத்தி
# grade pigment -> தர நிறமி
# concentration analysis -> செறிவு பகுப்பாய்வு
# raman spectroscopy -> ராமன் ஸ்பெக்ட்ரோஸ்கோபி
# food chemistry -> உணவு வேதியியல்
# spectroscopy -> ஸ்பெக்ட்ரோஸ்கோபி
# food fraud -> உணவு மோசடி
# fraud -> மோசடி
# olive pomace -> ஆலிவ் போமஸ்
# defective -> குறைபாடுள்ள
# volatile fraction -> கொந்தளிப்பான பின்னம்
# volatile -> எளிதில் ஆவியாகிற
# c6 alcohols -> சி 6 ஆல்கஹால்
# markers -> குறிப்பான்கள்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# alcohol -> ஆல்கஹால்
# hydro -> ஹைட்ரோ
# olive -> ஆலிவ்
# reactive oxygen / nitrogen species -> எதிர்வினை ஆக்ஸிஜன் / நைட்ரஜன் இனங்கள்
# lesions -> புண்கள்
# deoxyguanos -> டியோக்ஸிகுவானோஸ்
# stress -> மன அழுத்தம்
# poly ( -> பாலி (
# - ribose ) polymerase 1 -> - ரைபோஸ்) பாலிமரேஸ் 1
# dna repair -> டி.என்.ஏ பழுது
# cognitive impairment -> மனநல குறைபாடு
# biomark -> பயோமார்க்
# dna damage -> டி.என்.ஏ சேதம்
# molecular docking -> மூலக்கூறு நறுக்குதல்
# enzymes -> நொதிகள்
# olive oil -> ஆலிவ் எண்ணெய்
# inﬂammation -> ﬂ அமேஷன்
# bowel disease -> குடல் நோய்
# nutrients -> ஊட்டச்சத்துக்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# inﬂammation -> ﬂ அமேஷன்
# bowel -> குடல்
# disease -> நோய்
# molecules article determination -> மூலக்கூறுகள் கட்டுரை தீர்மானித்தல்
# triacy -> முக்கோண
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# rapeseed -> ராப்சீட்
# olive oil -> ஆலிவ் எண்ணெய்
# rapeseed oil -> ராப்சீட் எண்ணெய்
# triacylglycerols -> ட்ரையசில்கிளிசரல்கள்
# olive -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# - products -> - தயாரிப்புகள்
# olive -> ஆலிவ்
# tocopherols -> டோகோபெரோல்கள்
# tivar -> டிவார்
# antiox -> ஆன்டிஆக்ஸ்
# bioactive -> பயோஆக்டிவ்
# com - pounds -> கலவைகள்
# olive fly -> ஆலிவ் ஈ
# olive fly attacks -> ஆலிவ் பறக்கும் தாக்குதல்கள்
# verbascoside -> வெர்பாஸ்சைடு
# secoiridoid derivatives -> செகோயிரிடாய்டு வழித்தோன்றல்கள்
# phases -> கட்டங்கள்
# glucose -> குளுக்கோஸ்
# hydroxy -> ஹைட்ராக்ஸி
# olive -> ஆலிவ்
# resistance -> எதிர்ப்பு
# toxins -> நச்சுகள்
# chemotherapy -> கீமோதெரபி
# food and bioprocess -> உணவு மற்றும் பயோபிரசஸ்
# olive phenolic compounds -> ஆலிவ் பினோலிக் கலவைகள்
# conditioning -> கண்டிஷனிங்
# olive paste -> ஆலிவ் பேஸ்ட்
# volatile compounds -> கொந்தளிப்பான கலவைகள்
# cultivar -> சாகுபடி
# ultrasound -> அல்ட்ராசவுண்ட்
# ultrasonic -> மீயொலி
# hydro -> ஹைட்ரோ
# virgin -> கன்னி
# hydro -> ஹைட்ரோ
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olive - pomace oils -> ஆலிவ் - போமஸ் எண்ணெய்கள்
# techniques -> நுட்பங்கள்
# spectrometer -> ஸ்பெக்ட்ரோமீட்டர்
# mass spectrometry study -> வெகுஜன நிறமாலை ஆய்வு
# liver -> கல்லீரல்
# upper digestive tract -> மேல் செரிமான பாதை
# food chemistry -> உணவு வேதியியல்
# profile -> சுயவிவரம்
# phenolic metabolism -> பினோலிக் வளர்சிதை மாற்றம்
# science -> அறிவியல்
# olive oil secoiridoids -> ஆலிவ் ஆயில் செகோயிரிடாய்டுகள்
# metabolism -> வளர்சிதை மாற்றம்
# microbial metabolism -> நுண்ணுயிர் வளர்சிதை மாற்றம்
# olive oil -> ஆலிவ் எண்ணெய்
# metabolism -> வளர்சிதை மாற்றம்
# secoiridoids -> செகோயிரிடாய்டுகள்
# secoiridoids -> செகோயிரிடாய்டுகள்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# virgin olive oils -> கன்னி ஆலிவ் எண்ணெய்கள்
# urine samples -> சிறுநீர் மாதிரிகள்
# olive oil -> ஆலிவ் எண்ணெய்
# deterioration -> சரிவு
# edible oils -> உண்ணக்கூடிய எண்ணெய்கள்
# stability -> ஸ்திரத்தன்மை
# herring oil -> ஹெர்ரிங் எண்ணெய்
# neurological disorders -> நரம்பியல் கோளாறுகள்
# alzheimer ' s -> அல்சைமர்
# parkinson ' s diseases -> பார்கின்சனின் நோய்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# microarray analysis -> மைக்ரோஅரே பகுப்பாய்வு
# olive oil -> ஆலிவ் எண்ணெய்
# polyphenols -> பாலிபினால்கள்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# plant foods -> தாவர உணவுகள்
# fruit ripening process -> பழ பழுக்க வைக்கும் செயல்முறை
# animal diet -> விலங்குகளின் உணவு
# western -> மேற்கு
# olive -> ஆலிவ்
# alteration -> மாற்றுதல்
# adult -> வயது வந்தோர்
# least - squares regression -> குறைந்தது - சதுரங்கள் பின்னடைவு
# added - value components -> சேர்க்கப்பட்டது - மதிப்பு கூறுகள்
# phenolic -> பினோலிக்
# compounds -> கலவைகள்
# polyphenols -> பாலிபினால்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# phenolic -> பினோலிக்
# olive milling -> ஆலிவ் அரைத்தல்
# exploitation -> சுரண்டல்
# - products -> - தயாரிப்புகள்
# pheno -> பினோ
# and volatile -> மற்றும் கொந்தளிப்பான
# compounds -> கலவைகள்
# olive pomac -> ஆலிவ் போமாக்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# kinetic -> இயக்கவியல்
# lipid science -> லிப்பிட் அறிவியல்
# technology -> தொழில்நுட்பம்
# volatile compounds -> கொந்தளிப்பான கலவைகள்
# chromatography -> குரோமடோகிராபி
# food chemistry -> உணவு வேதியியல்
# deter -> தடுப்பு
# bitterness -> கசப்பு
# heating -> வெப்பமாக்கல்
# olive -> ஆலிவ்
# food chemistry -> உணவு வேதியியல்
# hot water dipping -> சூடான நீர் நீராடுகிறது
# olive -> ஆலிவ்
# virgin -> கன்னி
# food chemistry -> உணவு வேதியியல்
# volatile compounds -> கொந்தளிப்பான கலவைகள்
# analytical approaches -> பகுப்பாய்வு அணுகுமுறைகள்
# lipid science -> லிப்பிட் அறிவியல்
# sensory -> உணர்ச்சி
# ...
# bioactive ph -> பயோஆக்டிவ் பி.எச்
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# experimental gerontology -> சோதனை ஜெரண்டாலஜி
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# cognitive -> கும்மல்
# impairment -> குறைபாடு
# stress -> மன அழுத்தம்
# dna damage -> டி.என்.ஏ சேதம்
# alzheimer ' s disease and related disorders -> அல்சைமர் நோய் மற்றும் தொடர்புடைய கோளாறுகள்
# extra virgin olive oil -> கூடுதல் கன்னி ஆலிவ் எண்ணெய்
# dna damage -> டி.என்.ஏ சேதம்
# nitric oxide synthase -> நைட்ரிக் ஆக்சைடு சின்தேஸ்
# cognitive impairment -> மனநல குறைபாடு
# molecular docking -> மூலக்கூறு நறுக்குதல்
# stress -> மன அழுத்தம்
# reactive oxygen / nitrogen -> எதிர்வினை ஆக்ஸிஜன் / நைட்ரஜன்
# detrimental effects -> தீங்கு விளைவிக்கும் விளைவுகள்
# alzheimer ' s disease -> அல்சீமர் நோய்
# lesions -> புண்கள்
# deoxyguanos -> டியோக்ஸிகுவானோஸ்
# stress -> மன அழுத்தம்
# enzyme -> நொதி
# dna repair enzymes -> டி.என்.ஏ பழுதுபார்க்கும் என்சைம்கள்
# hydro -> ஹைட்ரோ
# diabetes mellitus -> நீரிழிவு நோய்
# intervention studies -> தலையீட்டு ஆய்வுகள்
# olive -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# gut - bacteria -> குடல் - பாக்டீரியா
# chain fatty - acids -> சங்கிலி கொழுப்பு - அமிலங்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# triacylglycer -> ட்ரையசில்கிளிசரால்
# acycl -> acycl
# saturated -> நிறைவுற்றது
# sterol -> ஸ்டெரால்
# olive -> ஆலிவ்
# palmitodiolein -> பால்மிட்டோடியோலின்
# tocopherol ratio -> டோகோபெரோல் விகிதம்
# alkane -> அல்கேன்
# sterol -> ஸ்டெரால்
# tocopherol -> டோகோபெரோல்
# gamma -> காமா
# tocopherol -> டோகோபெரோல்
# palmito -> பால்மிட்டோ
# pentacosane -> பென்டகோசேன்
# tricosane -> ட்ரைகோசேன்
# olive oil -> ஆலிவ் எண்ணெய்
# greek olive oils -> கிரேக்க ஆலிவ் எண்ணெய்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# greek -> கிரேக்கம்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# products -> தயாரிப்புகள்
# health outcomes -> சுகாதார விளைவுகள்
# analyses -> பகுப்பாய்வு
# cardiovascular disease -> இருதய நோய்
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# heart failure -> இதய செயலிழப்பு
# olive oil -> ஆலிவ் எண்ணெய்
# pheno -> பினோ
# compounds -> கலவைகள்
# expression -> வெளிப்பாடு
# of blood -> இரத்தம்
# pressure -> அழுத்தம்
# - related genes -> - தொடர்புடைய மரபணுக்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# fatty acids -> கொழுப்பு அமிலங்கள்
# vitamins -> வைட்டமின்கள்
# polyphenols -> பாலிபினால்கள்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# fluorescence -> ஒளிரும்
# fluorescence -> ஒளிரும்
# alteration -> மாற்றுதல்
# adult -> வயது வந்தோர்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# adult -> வயது வந்தோர்
# alteration -> மாற்றுதல்
# adult -> வயது வந்தோர்
# measurements -> அளவீடுகள்
# partial least - squares regression -> பகுதி குறைந்தது - சதுரங்கள் பின்னடைவு
# operating characteristics -> இயக்க பண்புகள்
# - oil -> - எண்ணெய்
# heating -> வெப்பமாக்கல்
# introduction -> அறிமுகம்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# vegetable oils -> தாவர எண்ணெய்கள்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# char - acteristic -> பண்பு
# olive oils -> ஆலிவ் எண்ணெய்கள்
# storage -> சேமிப்பு
# olive oil -> ஆலிவ் எண்ணெய்
# fatty acids alkyl este -> கொழுப்பு அமிலங்கள் அல்கைல் எஸ்டே
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olive leaves -> ஆலிவ் இலைகள்
# fruits -> பழங்கள்
# extrac - tion process -> பிரித்தெடுத்தல் செயல்முறை
# tunisian -> துனிசியன்
# extra - vir - gin olive oils -> கூடுதல் - கன்னி ஆலிவ் எண்ணெய்கள்
# olive drup -> ஆலிவ் ட்ரூப்
# olive oil -> ஆலிவ் எண்ணெய்
# analysis -> பகுப்பாய்வு
# fatty acids -> கொழுப்பு அமிலங்கள்
# squalene -> ஸ்குவாலீன்
# quality parameters -> தர அளவுருக்கள்
# seed oils -> விதை எண்ணெய்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# citrus -> சிட்ரஸ்
# olive -> ஆலிவ்
# citrus -> சிட்ரஸ்
# headspace volatile characterization -> ஹெட்ஸ்பேஸ் கொந்தளிப்பான தன்மை
# heads -> தலைகள்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olive -> ஆலிவ்
# smell -> வாசனை
# citrus -> சிட்ரஸ்
# food science -> உணவு அறிவியல்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olive pomace -> ஆலிவ் போமஸ்
# storage -> சேமிப்பு
# management -> மேலாண்மை
# near - infrared spectroscopy -> அருகில் - அகச்சிவப்பு ஸ்பெக்ட்ரோஸ்கோபி
# near - infrared analysis -> அருகில் - அகச்சிவப்பு பகுப்பாய்வு
# methods -> முறைகள்
# pomac -> போமாக்
# spectroscopy -> ஸ்பெக்ட்ரோஸ்கோபி
# fisher -> ஃபிஷர்
# transform -> உருமாற்றம்
# near - infrared spectroscopy -> அருகில் - அகச்சிவப்பு ஸ்பெக்ட்ரோஸ்கோபி
# infrared spectroscopy -> அகச்சிவப்பு ஸ்பெக்ட்ரோஸ்கோபி
# analysis -> பகுப்பாய்வு
# oil parameters -> எண்ணெய் அளவுருக்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# near infrared spectroscopy -> அகச்சிவப்பு ஸ்பெக்ட்ரோஸ்கோபி அருகே
# least -> குறைந்தது
# spectra -> ஸ்பெக்ட்ரா
# phenolics -> பினோலிக்ஸ்
# plant -> ஆலை
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# polar phenolic compounds -> துருவ பினோலிக் கலவைகள்
# olive -> ஆலிவ்
# surface tension -> மேற்பரப்பு பதற்றம்
# fatty acids -> கொழுப்பு அமிலங்கள்
# triglycerides -> ட்ரைகிளிசரைடுகள்
# phenolic compounds -> பினோலிக் கலவைகள்
# olive -> ஆலிவ்
# compounds -> கலவைகள்
# maltodextrin -> மால்டோடெக்ஸ்ட்ரின்
# properties -> பண்புகள்
# stability -> ஸ்திரத்தன்மை
# olive -> ஆலிவ்
# interfacial behavior -> இடைமுக நடத்தை
# olive -> ஆலிவ்
# phenolic compounds -> பினோலிக் கலவைகள்
# cooling treatment -> குளிரூட்டும் சிகிச்சை
# olive oil -> ஆலிவ் எண்ணெய்
# cooling treatment -> குளிரூட்டும் சிகிச்சை
# heat exchanger -> வெப்ப பரிமாற்றி
# olive oil -> ஆலிவ் எண்ணெய்
# volatile compounds -> கொந்தளிப்பான கலவைகள்
# temperature -> வெப்ப நிலை
# processed olives -> பதப்படுத்தப்பட்ட ஆலிவ்
# thermal exchanger -> வெப்ப பரிமாற்றி
# cooling -> குளிரூட்டும்
# volatile compounds -> கொந்தளிப்பான கலவைகள்
# origin -> தோற்றம்
# c6 aldehyde -> சி 6 ஆல்டிஹைட்
# yield -> மகசூல்
# cal characterization -> கால் தன்மை
# olive oils -> ஆலிவ் எண்ணெய்கள்
# north -> வடக்கு
# biophenols -> பயோஃபெனோல்கள்
# secoiridoids -> செகோயிரிடாய்டுகள்
# olive oil -> ஆலிவ் எண்ணெய்
# oleo science -> ஓலியோ அறிவியல்
# japan oil chemists ’ society -> ஜப்பான் எண்ணெய் வேதியியலாளர்கள் சமூகம்
# essential oil -> அத்தியாவசிய எண்ணெய்
# fatty acid profile -> கொழுப்பு அமில சுயவிவரம்
# introduction -> அறிமுகம்
# olive -> ஆலிவ்
# olives -> ஆலிவ்
# virgin -> கன்னி
# crushing -> நசுக்குதல்
# olive -> ஆலிவ்
# fatty -> கொழுப்பு
# oregano -> ஆர்கனோ
# essential oil -> அத்தியாவசிய எண்ணெய்
# olive -> ஆலிவ்
# electronic -> மின்னணு
# olive oils -> ஆலிவ் எண்ணெய்கள்
# electro -> மின்
# sensor -> சென்சார்
# virgin olive -> கன்னி ஆலிவ்
# chemometrics -> வேதியியல்
# olive -> ஆலிவ்
# vegetable oils -> தாவர எண்ணெய்கள்
# electronic nose -> மின்னணு மூக்கு
# argan oil -> ஆர்கன் எண்ணெய்
# vegetable oils -> தாவர எண்ணெய்கள்
# scattering -> சிதறல்
# vegetable oils -> தாவர எண்ணெய்கள்
# milk fat -> பால் கொழுப்பு
# sterol fraction -> ஸ்டெரோல் பின்னம்
# gas chromatography -> வாயு நிறமூர்த்தம்
# authentication -> அங்கீகார
# methods -> முறைகள்
# olive oil -> ஆலிவ் எண்ணெய்
# properties -> பண்புகள்
# natural phenols -> இயற்கை பினோல்கள்
# amyloid aggregation -> அமிலாய்டு திரட்டல்
# radicals -> தீவிரவாதிகள்
# drugs -> மருந்துகள்
# natural -> இயற்கை
# dry extract -> உலர் சாறு
# stress -> மன அழுத்தம்
# alzheimer ' -> முதுமறதி '
# disease -> நோய்
# alzheimer ' s disease -> அல்சீமர் நோய்
# nutrients review -> ஊட்டச்சத்துக்கள் மதிப்பாய்வு
# phenolic compounds -> பினோலிக் கலவைகள்
# olea europaea -> ஓலியா யூரோபியா
# biomedical sciences -> பயோமெடிக்கல் சயின்சஸ்
# matrix -> அணி
# fatty acids -> கொழுப்பு அமிலங்கள்
# extra -> கூடுதல்
# phenolics -> பினோலிக்ஸ்
# hydro -> ஹைட்ரோ
# oleuropein -> ஒலூரோபின்
# chromatographic ﬁngerprinting -> குரோமடோகிராஃபிக் ﬁ ngerprinting
# food authentication -> உணவு அங்கீகாரம்
# olive oil -> ஆலிவ் எண்ணெய்
# va - rieti -> வா - ரிட்டி
# extra virgin olive oils -> கூடுதல் கன்னி ஆலிவ் எண்ணெய்கள்
# molecules -> மூலக்கூறுகள்
# olive oil -> ஆலிவ் எண்ணெய்
# citrus -> சிட்ரஸ்
# nutraceutical -> ஊட்டச்சத்து
# sensorial features -> சென்ஸோரியல் அம்சங்கள்
# research -> ஆராய்ச்சி
# nutraceuticals -> ஊட்டச்சத்து மருந்துகள்
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# citrus leaves -> சிட்ரஸ் இலைகள்
# citrus leaf addition -> சிட்ரஸ் இலை கூடுதலாக
# olive oils -> ஆலிவ் எண்ணெய்கள்
# citrus -> சிட்ரஸ்
# characterization -> தன்மை
# fingerprinting -> கைரேகை
# virgin -> கன்னி
# olive -> ஆலிவ்
# of lipid science -> லிப்பிட் அறிவியல்
# analytical methods -> பகுப்பாய்வு முறைகள்
# geographical origin classification -> புவியியல் தோற்றம் வகைப்பாடு
# olive oils -> ஆலிவ் எண்ணெய்கள்
# metabolic fingerprinting approach -> வளர்சிதை மாற்ற கைரேகை அணுகுமுறை
# mass spectrometry -> பெருமளவிலான நிறமாலையியல்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# phenolic characterization -> பினோலிக் தன்மை
# classification -> வகைப்பாடு
# olive oils -> ஆலிவ் எண்ணெய்கள்
# aromatic hydrocarbon -> நறுமண ஹைட்ரோகார்பன்
# concentration -> செறிவு
# food chemistry -> உணவு வேதியியல்
# mineral oil -> கனிம எண்ணெய்
# hydrocarbons -> ஹைட்ரோகார்பன்கள்
# gas chromatography -> வாயு நிறமூர்த்தம்
# hydrocarbons -> ஹைட்ரோகார்பன்கள்
# memory effects -> ...error in translation...
# liquid chromatography -> திரவ நிறமூர்த்தம்
# chromatography -> குரோமடோகிராபி
# chromatography -> ...error in translation...
# liquid chromatography -> திரவ நிறமூர்த்தம்
# chromatography -> குரோமடோகிராபி
# chromatography -> குரோமடோகிராபி
# chromatography -> குரோமடோகிராபி
# eclipta alba -> கிரகண ஆல்பா
# hepatotoxicity -> ஹெபடோடாக்சிசிட்டி
# olive oil -> ஆலிவ் எண்ணெய்
# corn oil -> சோள எண்ணெய்
# food che -> உணவு சே
# lycorine -> லைகோரின்
# carbon tetrachloride -> கார்பன் டெட்ராக்ளோரைடு
# toxicity -> நச்சுத்தன்மை
# swiss albino -> சுவிஸ் அல்பினோ
# drugs -> மருந்துகள்
# lignans -> ...error in translation...
# liver -> கல்லீரல்
# injury -> காயம்
# tea seed oil -> தேயிலை விதை எண்ணெய்
# aspects -> ...error in translation...
# virgin olive -> கன்னி ஆலிவ்
# mediated -> மத்தியஸ்தம்
# inﬂammatory diseases -> ...error in translation...
# dietary ω -> உணவு
# fatty acid -> கொழுப்பு அமிலம்
# anti - -> ...error in translation...
# allergic eﬀect -> ஒவ்வாமை மின் ect
# 18 - epoxyeicosatetraenoic acid -> 18 - எபோக்சீயிகோசாடெட்ரேனோயிக் அமிலம்
# food chemistry -> உணவு வேதியியல்
# raman evaluation -> ராமன் மதிப்பீடு
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# attack -> தாக்குதல்
# olive oil -> ஆலிவ் எண்ணெய்
# raman spectroscopy -> ராமன் ஸ்பெக்ட்ரோஸ்கோபி
# lutein -> லூடீன்
# olive fly -> ஆலிவ் ஈ
# olive -> ஆலிவ்
# carotenoids -> ...error in translation...
# water -> தண்ணீர்
# olive -> ஆலிவ்
# planktonic cells -> பிளாங்க்டோனிக் செல்கள்
# bioﬁlm formation -> உயிர் ﬁ lm உருவாக்கம்
# arcobacter - like -> ஆர்கோபாக்டர் - போன்றது
# olive -> ...error in translation...
# planktonic cells -> பிளாங்க்டோனிக் செல்கள்
# arcobacter -> ஆர்கோபாக்டர்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# arcob -> ஆர்கோப்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olive -> ஆலிவ்
# chemical analysis -> வேதியியல் பகுப்பாய்வு
# olive oil -> ஆலிவ் எண்ணெய்
# profile -> சுயவிவரம்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# phenolic compounds -> பினோலிக் கலவைகள்
# liquid chromatography -> திரவ நிறமூர்த்தம்
# electrospray ionisation -> எலக்ட்ரோஸ்ப்ரே அயனியாக்கம்
# mass spectrometry -> பெருமளவிலான நிறமாலையியல்
# sensory analysis -> உணர்ச்சி பகுப்பாய்வு
# organoleptic assessment -> ஆர்கனோலெப்டிக் மதிப்பீடு
# sensory analysis -> உணர்ச்சி பகுப்பாய்வு
# olive oil -> ஆலிவ் எண்ணெய்
# methods -> முறைகள்
# olive -> ...error in translation...
# domestic frying habits -> உள்நாட்டு வறுக்கப்படுகிறது பழக்கம்
# consumer ’ s preferences -> நுகர்வோரின் விருப்பத்தேர்வுகள்
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# acrylamide formation -> அக்ரிலாமைடு உருவாக்கம்
# compound -> கூட்டு
# virgin -> கன்னி
# virgin olive oil -> கன்னி ஆலிவ் எண்ணெய்
# analytical tests -> பகுப்பாய்வு சோதனைகள்
# uv - vis -> புற ஊதா - விஸ்
# electro -> மின்
# molecular sciences -> மூலக்கூறு அறிவியல்
# olive -> ஆலிவ்
# animal -> ...error in translation...
# fatty acids -> கொழுப்பு அமிலங்கள்
# vitamins -> வைட்டமின்கள்
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# olive oil -> ஆலிவ் எண்ணெய்
# cardiovascular -> இருதய
# olive oil -> ஆலிவ் எண்ணெய்
# platelet -> பிளேட்லெட்
# obesity -> உடல் பருமன்
# platelet -> பிளேட்லெட்
# olive oil -> ஆலிவ் எண்ணெய்
# olive oil -> ஆலிவ் எண்ணெய்
# plate -> தட்டு
# activation -> செயல்படுத்தல்
# diet composition -> உணவு கலவை
# olive oil -> ஆலிவ் எண்ணெய்
# extraction -> பிரித்தெடுத்தல்
# extraction -> பிரித்தெடுத்தல்
# quality -> தரம்
# phenolic content -> பினோலிக் உள்ளடக்கம்
# stability -> ஸ்திரத்தன்மை
# olive oil -> ...error in translation...
# cancer -> புற்றுநோய்
# chemotherapy -> கீமோதெரபி
# olive oil polyphenols -> ஆலிவ் ஆயில் பாலிபினால்கள்
# hydroxytyrosol -> ஹைட்ராக்ஸிடிரோசோல்
# tyro - sol -> டைரோ - சோல்
# oleuropein -> ஒலூரோபின்
# metastasi -> மெட்டாஸ்டாசி
# cancer -> புற்றுநோய்
# analysis -> பகுப்பாய்வு
# structured -> கட்டமைக்கப்பட்ட
# equilibrium -> சமநிலை
# porosis -> போரோஸிஸ்
# balance training -> இருப்பு பயிற்சி
# biomarkers -> பயோமார்க்ஸ்
# admission -> அனுமதி
# fracture -> எலும்பு முறிவு
# fractures -> எலும்பு முறிவுகள்
# imaging -> இமேஜிங்
# inhibit -> தடுக்கவும்
# cells -> செல்கள்
# gamma -> ...error in translation...
# linolenic acid -> ...error in translation...
# bone status -> எலும்பு நிலை
# free urinary collagen -> இலவச சிறுநீர் கொலாஜன்
# drupes -> drupes
# ultrasound -> அல்ட்ராசவுண்ட்
# olive -> ஆலிவ்
# mobility spectrometry -> இயக்கம் நிறமாலை
# virgin -> கன்னி
# sensory analysis -> உணர்ச்சி பகுப்பாய்வு
# olive -> ஆலிவ்
# - residue oil -> - எச்ச எண்ணெய்
# sensory evaluation -> உணர்ச்சி மதிப்பீடு
# virgin olive -> கன்னி ஆலிவ்
# fraud -> மோசடி
# virgin olive -> கன்னி ஆலிவ்
# sensory defects -> உணர்ச்சி குறைபாடுகள்
# cardiovascular disease -> இருதய நோய்
# cardiovascular disease prevention -> இருதய நோய் தடுப்பு
# prevention -> தடுப்பு
# macro -> பெரு
# lipoprotein -> லிப்போபுரோட்டீன்
# lipoprotein -> லிப்போபுரோட்டீன்
# lipop -> லிபாப்
# macrophages -> மேக்ரோபேஜ்கள்
# artery -> தமனி
# oxygen radicals -> ஆக்ஸிஜன் தீவிரவாதிகள்
# vitamin e -> வைட்டமின் இ
# corona -> கொரோனா
# hydro -> ஹைட்ரோ
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# corona -> கொரோனா
# olive oils -> ஆலிவ் எண்ணெய்கள்
# extra -> கூடுதல்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# vegetable -> காய்கறி
# olive -> ஆலிவ்
# diffusion coefficients -> பரவல் குணகம்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# vegetable oils -> தாவர எண்ணெய்கள்
# adult -> வயது வந்தோர்
# genetic algorithms -> மரபணு வழிமுறைகள்
# measurement -> அளவீட்டு
# squalene -> ஸ்குவாலீன்
# melting -> உருகுதல்
# near - infrared spectrometry -> அருகில் - அகச்சிவப்பு நிறமாலை
# near - infrared -> அகச்சிவப்புக்கு அருகில்
# nir ) spectra -> ...error in translation...
# partial least squares -> பகுதி குறைந்தபட்ச சதுரங்கள்
# health -> ஆரோக்கியம்
# health -> ஆரோக்கியம்
# olive oil -> ஆலிவ் எண்ணெய்
# authenticity -> நம்பகத்தன்மை
# orbit -> வட்ட பாதையில் சுற்றி
# olive -> ஆலிவ்
# orbit -> வட்ட பாதையில் சுற்றி
# approaches -> அணுகுமுறைகள்
# pharmacognosy -> ...error in translation...
# natural products -> ...error in translation...
# edible vegetable -> உண்ணக்கூடிய காய்கறி
# olive -> ஆலிவ்
# edible oil -> சமையல் எண்ணெய்
# fatty acids -> கொழுப்பு அமிலங்கள்
# nutrients -> ஊட்டச்சத்துக்கள்
# olive oil -> ஆலிவ் எண்ணெய்
# dietary pattern -> உணவு முறை
# mediterranean -> மத்திய தரைக்கடல்
# bread -> ...error in translation...
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# virgin -> கன்னி
# olive -> ஆலிவ்
# ultrasonics sonochemistry -> அல்ட்ராசோனிக்ஸ் சோனோ கெமிஸ்ட்ரி
# ultrasound machine -> அல்ட்ராசவுண்ட் இயந்திரம்
# ultrasound -> அல்ட்ராசவுண்ட்
# malaxation -> மாலாக்ஸேஷன்
# ultrasound -> அல்ட்ராசவுண்ட்
# ultrasound -> அல்ட்ராசவுண்ட்
# ultrasound -> அல்ட்ராசவுண்ட்
# olive -> ஆலிவ்
# ultrasound -> அல்ட்ராசவுண்ட்
# treatment -> சிகிச்சை
# ultrasound -> அல்ட்ராசவுண்ட்
# spectrochimic -> ஸ்பெக்ட்ரோகிமிக்
# biomolecular spectroscopy -> உயிர் மூலக்கூறு ஸ்பெக்ட்ரோஸ்கோபி
# olive -> ...error in translation...
# infrared spectroscopy -> அகச்சிவப்பு ஸ்பெக்ட்ரோஸ்கோபி
# learning -> கற்றல்
# selection -> தேர்வு
# olive -> ஆலிவ்
# olive -> ஆலிவ்
# near infrared spectroscopy -> அகச்சிவப்பு ஸ்பெக்ட்ரோஸ்கோபி அருகே
# olive oil -> ஆலிவ் எண்ணெய்
# artificial intelligence model -> செயற்கை நுண்ணறிவு மாதிரி
# analysis -> பகுப்பாய்வு
# food authentication -> உணவு அங்கீகாரம்
# liquid chromatography -> திரவ நிறமூர்த்தம்
# electrospray -> எலக்ட்ரோஸ்ப்ரே
# mass spectrometry analytical -> ...error in translation...
# olive oil -> ஆலிவ் எண்ணெய்
# macro -> பெரு
# bahrami2 -> பஹ்ராமி 2
# chilling -> குளிர்வித்தல்
# freezing -> உறைபனி
# injuries -> ...error in translation...
# olive -> ஆலிவ்
# freezing -> உறைபனி
# olive -> ஆலிவ்
# common -> பொது
# extracted oils -> பிரித்தெடுக்கப்பட்ட எண்ணெய்கள்
# fruits -> பழங்கள்
# pro - cesses -> செயல்முறைகள்
# vegetable -> காய்கறி
# nutritional compounds -> ஊட்டச்சத்து கலவைகள்
# sterol -> ஸ்டெரால்
# olive oils -> ஆலிவ் எண்ணெய்கள்
# olea europaea -> ஓலியா யூரோபியா
# fatty acids -> கொழுப்பு அமிலங்கள்
# hydro -> ஹைட்ரோ
# olive oil -> ...error in translation...
# olive -> ஆலிவ்
# products -> தயாரிப்புகள்
# hydro -> ஹைட்ரோ
# olive oil -> ஆலிவ் எண்ணெய்
# olive -> ஆலிவ்
# evaluation -> மதிப்பீடு
# greece -> கிரீஸ்
# content -> உள்ளடக்கம்
# olive oil -> ஆலிவ் எண்ணெய்
# multivar -> ...error in translation...
# analysis -> பகுப்பாய்வு
# parallel factor analysis -> இணை காரணி பகுப்பாய்வு
# spectroscopy -> ஸ்பெக்ட்ரோஸ்கோபி

# %%
# Out:
# ['Sign_symptom',
#  'Biological_structure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Medication',
#  'Medication',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Medication',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Therapeutic_procedure',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Therapeutic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Therapeutic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Therapeutic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Therapeutic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Medication',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Therapeutic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Therapeutic_procedure',
#  'Diagnostic_procedure',
#  'Therapeutic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Therapeutic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Biological_structure',
#  'Medication',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Medication',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Disease_disorder',
#  'Medication',
#  'Medication',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Clinical_event',
#  'Disease_disorder',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Medication',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Biological_structure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Medication',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Therapeutic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Medication',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Medication',
#  'Disease_disorder',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Therapeutic_procedure',
#  'Therapeutic_procedure',
#  'Therapeutic_procedure',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Disease_disorder',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Therapeutic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Therapeutic_procedure',
#  'Therapeutic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Therapeutic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Medication',
#  'Medication',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Therapeutic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Therapeutic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Medication',
#  'Medication',
#  'Medication',
#  'Sign_symptom',
#  'Disease_disorder',
#  'Medication',
#  'Medication',
#  'Sign_symptom',
#  'Therapeutic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Medication',
#  'Diagnostic_procedure',
#  'Biological_structure',
#  'Medication',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Sign_symptom',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Therapeutic_procedure',
#  'Medication',
#  'Sign_symptom',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Therapeutic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Therapeutic_procedure',
#  'Disease_disorder',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Therapeutic_procedure',
#  'Therapeutic_procedure',
#  'Therapeutic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Medication',
#  'Medication',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Sign_symptom',
#  'Biological_structure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Diagnostic_procedure',
#  'Medication',
#  'Sign_symptom',
#  'Medication',
#  'Therapeutic_procedure',
#  'Medication',
#  'Diagnostic_procedure',
#  'Sign_symptom',
#  'Medication',
#  'Medication',
#  'Diagnostic_procedure',
#  ...]

# %%
import csv


# Zip the three lists together to create rows for the CSV
data_rows = zip(word_list, tamil_translations, entity_list)

# Specify the file name
csv_file_path = "/content/drive/MyDrive/NLP Pubmed/english_tamil_dict_output.csv"

# Open the CSV file in write mode and write the rows
with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Write the header row
    writer.writerow(["Word", "Tamil Translation", "Entity"])

    # Write the data rows
    writer.writerows(data_rows)

print(f"CSV file '{csv_file_path}' created successfully.")
# Out:
# CSV file '/content/drive/MyDrive/NLP Pubmed/english_tamil_dict_output.csv' created successfully.

# %%
import pandas as pd
df = pd.read_csv(csv_file_path)
df.head()
# Out:
#        Word Tamil Translation                Entity
# 0     fungi            பூஞ்சை          Sign_symptom
# 1     olive             ஆலிவ்  Biological_structure
# 2  freezing            உறைபனி          Sign_symptom
# 3    fluids         திரவங்கள்  Diagnostic_procedure
# 4    virgin             கன்னி  Diagnostic_procedure
